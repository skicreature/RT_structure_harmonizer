# %%
import fnmatch
import json
import multiprocessing
import os
import re  # noqa may use in the future
import pathlib
from functools import partial
from multiprocessing import Pool
from typing import Any, TypeVar, Type, Optional, List, Dict, Union, cast  # noqa

import tkinter as tk
from tkinter import ttk, simpledialog
import pandas as pd
import numpy as np
import pandas as pd
from fuzzywuzzy import fuzz
from openpyxl import load_workbook  # noqa
from progress.bar import Bar
from pydicom import dcmread

from structure_harmonizer import *
import pathlib
# Out:
# c:\Users\wd982598\.virtualenvs\structure_harmonization-AfCjJfLJ\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# set the directory to search
# directory = '/pct_ids/users/wd982598/test_requite'
directory = pathlib.Path(r'C:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\test_requite')
output_file =r'structure_dictionary'
TG_263_file_path=pathlib.Path(r'C:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\TG263_Nomenclature_Worksheet_20170815.xls')
#directory = '/mnt/t/Batch_1/'

# Define the match quality threshold
threshold = 88

# Create an instance of StructureHarmonizer and call the harmonize_structures method
harmonizer = StructureHarmonizer(
    directory, 
    output_file, 
    TG_263_file_path, 
    threshold=threshold, 
    roi_json_path='json_rtstruct_dict_new.json'
    )

# %%
harmonizer.load_json_roi_dict(harmonizer.roi_json_path)
harmonizer.get_all_TG263names()
harmonizer.load_harmonized_df('structure_dictionary.csv_scores.csv')
harmonizer.harmonized_df_matches = harmonizer.harmonized_df.applymap(harmonizer.match_method) #type: ignore
# Out:
# C:\Users\wd982598\AppData\Local\Temp\ipykernel_29408\1404291791.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   harmonizer.harmonized_df_matches = harmonizer.harmonized_df.applymap(harmonizer.match_method) #type: ignore

# %%
roi_dict_size = len(harmonizer.roi_dict)
TG263_dict_size = len(harmonizer.TG263_data_dict)
print('roi_dict_size: ', roi_dict_size, '||', 'TG263_dict_size: ', TG263_dict_size)
assert roi_dict_size == 3555
assert TG263_dict_size == 717
# Out:
# roi_dict_size:  3555 || TG263_dict_size:  717

# %%
F= harmonizer.prioritize_rt_structures()
print(F)
# Out:
# ['dummy_index', ' intestino tc1', ' paloma', '(D) Blad OL', '(D) Blad Opt', '(D) CD OL', '(D) CD OPT', '(D) LB OL', '(D) PRSV OL', '(D) PRSV OPT', '(D) PTV 70.2 OL', '(D) Rect Opt', '(D)Ptv 70.2 opt', '(PTV2-dig)-rct', '(ptv pelvis)', '(ptvopt-dig)-rec', '1', '10 Gy 2015', '100%buiten PTV2', '2', '2MARKUP_PTVA', '2OPT_Bladder', '2OPT_Bowel', '2OPT_Bowel+PTVA', '2OPT_PTVA', '2OPT_PTVA_BST', '2OPT_PTVA_BST2', '2OPT_PTVB', '2OPT_PTVB BST', '2OPT_PTVB_CTRL', '2OPT_Rectum', '2PTVA_Ring', '2PTVB', '2PTVexp', '3', '3Reperi', '4', '4536.80cGy', '51.3gy', '5350.00cGy', '5350.00cGy_1', '62,51G_exPTV1', '62.51G_exPTV1', '6420.00cGy', '72.5%', '76', 'ABO', 'AJM Bowel', 'AJM bladder', 'AJM rectum', 'ALL_Targets_exp', 'ALLtarget', 'ALO_In_Vivo_PT', 'ANO', 'ANO TC1', 'ANO TC2', 'ANORETTO', 'ANOin', 'ANSA', 'ANSE', 'ANSE 0.5mm', 'ANSE INTESTINALI', 'ANT_In_Vivo_PT', 'APEX', 'ARIA', 'ARO_In_Vivo_PT', 'ARTEFACT', 'ARTIFACT', 'AVOID', 'A_inPTV1', 'Abdominalhoehle', 'AcqIsocenter', 'Acqua', 'Addbody', '
# ...

# %%
#harmonizer.review_matches_gui()

# %%
#F=HarmonizerGUI(harmonizer)
#F.run_review()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 2
#       1 F=HarmonizerGUI(harmonizer)
# ----> 2 F.run_review()
#
# AttributeError: 'HarmonizerGUI' object has no attribute 'run_review'

# %%
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\users\wd982598\.pyenv\pyenv-win\versions\3.10.11\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py", line 714, in on_value_change
#     self.get_top_rows(search_column)
#   File "c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py", line 705, in get_top_rows
#     int(self.num_results.get()), roi
# ValueError: invalid literal for int() with base 10: ''
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\users\wd982598\.pyenv\pyenv-win\versions\3.10.11\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py", line 714, in on_value_change
# ...
