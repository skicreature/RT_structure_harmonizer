# %%
import os
import fnmatch
import pydicom
from pydicom import dcmread
import numpy as np
import pandas as pd
from openpyxl import load_workbook
from fuzzywuzzy import fuzz
import re
from structure_harmonizer import StructureHarmonizer
import pathlib
#from structure_regex import generate_structure_name

# set the directory to search
# directory = '/pct_ids/users/wd982598/test_requite'
directory = pathlib.Path(r'C:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\test_requite')
output_file =r'structure_dictionary'
TG_263_file_path=pathlib.Path(r'C:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\TG263_Nomenclature_Worksheet_20170815.xls')
#directory = '/mnt/t/Batch_1/'

# Define the match quality threshold
threshold = 88

# Create an instance of StructureHarmonizer and call the harmonize_structures method
harmonizer = StructureHarmonizer(
    directory, 
    output_file, 
    TG_263_file_path, 
    threshold=threshold, 
    roi_json_path='json_rtstruct_dict_new.json'
    )
# Out:
# c:\Users\wd982598\.virtualenvs\structure_harmonization-AfCjJfLJ\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
harmonizer.load_json_roi_dict(harmonizer.roi_json_path)

# %%
F=harmonizer.roi_dict.values()
print(F)
# Out:
# dict_values([<structure_harmonizer.RTStruct object at 0x000002617E4DCD90>, <structure_harmonizer.RTStruct object at 0x000002617E4DCEB0>, <structure_harmonizer.RTStruct object at 0x000002617E4DD0C0>, <structure_harmonizer.RTStruct object at 0x000002617E4DD090>, <structure_harmonizer.RTStruct object at 0x000002617E4DCEE0>, <structure_harmonizer.RTStruct object at 0x000002617E4DD0F0>, <structure_harmonizer.RTStruct object at 0x000002617E4DD570>, <structure_harmonizer.RTStruct object at 0x000002617E4DD5D0>, <structure_harmonizer.RTStruct object at 0x000002617E4DD150>, <structure_harmonizer.RTStruct object at 0x000002617E4DD660>, <structure_harmonizer.RTStruct object at 0x000002617E4DD630>, <structure_harmonizer.RTStruct object at 0x000002617E4DD600>, <structure_harmonizer.RTStruct object at 0x000002617E4DD690>, <structure_harmonizer.RTStruct object at 0x000002617E4DDE10>, <structure_harmonizer.RTStruct object at 0x000002617E4DDE70>, <structure_harmonizer.RTStruct object at 0x000002617E4DDCF0>, <structure_harmonizer.RTStruct object at 0x000002617E4DDF00>, <structure_harmonizer.RTStruct object at 0x000002617E4DDED0>, <structure_harmonizer.RTStruct object at 0x000002617E4DDEA0>, <structure_harmonizer.RTStruct object at 0x000002617E4DDF30>, <structure_harmonizer.RTStruct object at 0x000002617E4DE0B0>, <structure_harmonizer.RTStruct object at 0x000002617E4DED10>, <structure_harmonizer.RTStruct object at 0x000002617E4DDF90>, <structure_harmonizer.RTStruct object at 0x000002617E4DEDA0>, <structure_harmonizer.RTStruct object at 0x000002617E4DED70>, <structure_harmonizer.RTStruct object at 0x000002617E4DED40>, <structure_harmonizer.RTStruct object at 0x000002617E4DEDD0>, <structure_harmonizer.RTStruct object at 0x000002617E4DEF50>, <structure_harmonizer.RTStruct object at 0x000002617E4DEFB0>, <structure_harmonizer.RTStruct object at 0x000002617E4DEE30>, <structure_harmonizer.RTStruct object at 0x000002617E4DF040>, <structure_harmonizer.RTStruct object at 0x000002617E4DF010>, <structure_harmonizer.RTStruct object at 0x000002617E4DEFE0>, <structure_harmonizer.RTStruct object at 0x000002617E4DF070>, <structure_harmonizer.RTStruct object at 0x000002617E4DF1F0>, <structure_harmonizer.RTStruct object at 0x000002617E4DF250>, <structure_harmonizer.RTStruct object at 0x000002617E4DF0D0>, <structure_harmonizer.RTStruct object at 0x000002617E4DF2E0>, <structure_harmonizer.RTStruct object at 0x000002617E4DF340>, <structure_harmonizer.RTStruct object at 0x000002617E4DF280>, <structure_harmonizer.RTStruct object at 0x000002617E4DF310>, <structure_harmonizer.RTStruct object at 0x000002617E4DFEE0>, <structure_harmonizer.RTStruct object at 0x000002617E4DFE80>, <structure_harmonizer.RTStruct object at 0x000002617E4DF370>, <structure_harmonizer.RTStruct object at 0x000002617E4DFDF0>, <structure_harmonizer.RTStruct object at 0x000002617E4DFE20>, <structure_harmonizer.RTStruct object at 0x000002617E4DFE50>, <structure_harmonizer.RTStruct object at 0x000002617E4DFDC0>, <structure_harmonizer.RTStruct object at 0x000002617E4DFC40>, <structure_harmonizer.RTStruct object at 0x000002617E4DFBE0>, <structure_harmonizer.RTStruct object at 0x000002617E4DFD60>, <structure_harmonizer.RTStruct object at 0x000002617E4DFB50>, <structure_harmonizer.RTStruct object at 0x000002617E4DFB80>, <structure_harmonizer.RTStruct object at 0x000002617E4DFBB0>, <structure_harmonizer.RTStruct object at 0x000002617E4DFB20>, <structure_harmonizer.RTStruct object at 0x000002617E4DF9A0>, <structure_harmonizer.RTStruct object at 0x000002617E4DF940>, <structure_harmonizer.RTStruct object at 0x000002617E4DFAC0>, <structure_harmonizer.RTStruct object at 0x000002617E4DF8B0>, <structure_harmonizer.RTStruct object at 0x000002617E4DF910>, <structure_harmonizer.RTStruct object at 0x000002617E4DF8E0>, <structure_harmonizer.RTStruct object at 0x000002617E4DF880>, <structure_harmonizer.RTStruct object at 0x000002617E4DF700>, <structure_harmonizer.RTStruct object at 0x000002617E4DF6A0>, <structure_harmoniz ...

# %%
harmonizer.TG_263_df.head()
# Out:
#   Target Type Major Category   Minor Category Anatomic Group  N Characters  \
# 0    Anatomic         Artery            Aorta         Thorax             7
# 1    Anatomic         Artery            Aorta         Thorax            11
# 2    Anatomic         Artery  Brachiocephalic         Thorax            15
# 3    Anatomic         Artery          Carotid  Head and Neck             9
# 4    Anatomic         Artery          Carotid  Head and Neck            11
#
#   TG263-Primary Name TG-263-Reverse Order Name             Description  \
# 0            A_Aorta                   Aorta_A                   Aorta
# 1        A_Aorta_Asc               Asc_Aorta_A         Ascending Aorta
# 2    A_Brachiocephls           Brachiocephls_A  Brachiocephalic Artery
# 3          A_Carotid                 Carotid_A   Common Carotid Artery
# 4        A_Carotid_L               L_Carotid_A          Carotid Artery
#
#     FMAID Unnamed: 9
# 0  3734.0        NaN
# 1  3736.0        NaN
# 2  3932.0        NaN
# 3  3939.0        NaN
# 4  4058.0        NaN

# %%
print(harmonizer.TG_263_prime_name_col)
# Out:
# TG263-Primary Name

# %%
harmonizer.get_all_TG263names()

# %%
roi_dict_size = len(harmonizer.roi_dict)
TG263_dict_size = len(harmonizer.TG263_data_dict)
print('roi_dict_size: ', 'roi_dict_size', '||', 'TG263_dict_size: ', TG263_dict_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 roi_dict_size = len(harmonizer.roi_dict)
#       2 TG263_dict_size = len(harmonizer.TG263_data_dict)
#       3 print('roi_dict_size: ', 'roi_dict_size', '||', 'TG263_dict_size: ', TG263_dict_size)
#
# NameError: name 'harmonizer' is not defined

# %%
for key,val in harmonizer.TG263_data_dict.items():
    print(key)
    print(val.synonyms)
    print(val.categories)
    print(val.target_type)
    print(val.FMAID)
# Out:
# A_Aorta
# ['Aorta_A', 'A_Aorta']
# ['Artery', 'Aorta', 'Thorax']
# Anatomic
# 3734.0
# A_Aorta_Asc
# ['A_Aorta_Asc', 'Asc_Aorta_A']
# ['Artery', 'Aorta', 'Thorax']
# Anatomic
# 3736.0
# A_Brachiocephls
# ['Brachiocephls_A', 'A_Brachiocephls']
# ['Artery', 'Brachiocephalic', 'Thorax']
# Anatomic
# 3932.0
# A_Carotid
# ['Carotid_A', 'A_Carotid']
# ['Artery', 'Carotid', 'Head and Neck']
# Anatomic
# 3939.0
# A_Carotid_L
# ['L_Carotid_A', 'A_Carotid_L']
# ['Artery', 'Carotid', 'Head and Neck']
# Anatomic
# 4058.0
# A_Carotid_R
# ['A_Carotid_R', 'R_Carotid_A']
# ['Artery', 'Carotid', 'Head and Neck']
# Anatomic
# 3941.0
# A_Celiac
# ['A_Celiac', 'Celiac_A']
# ['Artery', 'Celiac', 'Abdomen']
# Anatomic
# 50737.0
# A_Coronary
# ['Coronary_A', 'A_Coronary']
# ['Artery', 'Coronary', 'Head and Neck']
# Anatomic
# 49893.0
# A_Coronary_L
# ['A_Coronary_L', 'L_Coronary_A']
# ['Artery', 'Coronary', 'Thorax']
# Anatomic
# 50040.0
# A_Coronary_R
# ['A_Coronary_R', 'R_Coronary_A']
# ['Artery', 'Coronary', 'Thorax']
# Anatomic
# 50039.0
# A_Femoral_Cflx_L
# ['L_Cflx_Femoral_A', 'A_Femoral_Cflx_L']
# ['Artery', 'Femoral', 'Limb']
# Anatomic
# nan
# A_Femoral_Cflx_R
# ['A_Femoral_Cflx_R', 'R_Cflx_Femoral_A']
# ['Artery', 'Femoral', 'Limb']
# Anatomic
# nan
# A_Femoral_L
# ['L_Femoral_A', 'A_Femoral_L']
# ['Artery', 'Femoral', 'Limb']
# Anatomic
# 70250.0
# A_Femoral_R
# ['R_Femoral_A', 'A_Femoral_R']
# ['Artery', 'Femoral', 'Limb']
# Anatomic
# 70249.0
# A_Humeral_Cflx_L
# ['L_Cflx_Humeral_A', 'A_Humeral_Cflx_L']
# ['Artery', 'Humeral', 'Limb']
# Anatomic
# nan
# A_Humeral_Cflx_R
# ['A_Humeral_Cflx_R', 'R_Cflx_Humeral_A']
# ['Artery', 'Humeral', 'Limb']
# Anatomic
# nan
# A_Humeral_L
# ['A_Humeral_L', 'L_Humeral_A']
# ['Artery', 'Humeral', 'Limb']
# Anatomic
# nan
# A_Humeral_R
# ['A_Humeral_R', 'R_Humeral_A']
# ['Artery', 'Humeral', 'Limb']
# Anatomic
# nan
# A_Hypophyseal_I
# ['A_Hypophyseal_I', 'I_Hypophyseal_A']
# ['Artery', 'Hypophyseal', 'Head and Neck']
# Anatomic
# 49846.0
# A_Hypophyseal_S
# ['S_Hypophyseal_A', 'A_Hypophyseal_S']
# ['Artery', 'Hypophyseal', 'Head and Neck']
# Anatomic
# 49849.0
# A_Iliac_Cflx_L
# ['A_Iliac_Cflx_L', 'L_Cflx_Iliac_A']
# ['Artery', 'Iliac', 'Pelvis']
# Anatomic
# nan
# A_Iliac_Cflx_R
# ['A_Iliac_Cflx_R', 'R_Cflx_Iliac_A']
# ['Artery', 'Iliac', 'Pelvis']
# Anatomic
# nan
# A_Iliac_Ext_L
# ['L_Ext_Iliac_A', 'A_Iliac_Ext_L']
# ['Artery', 'Iliac', 'Pelvis']
# Anatomic
# 18807.0
# A_Iliac_Ext_R
# ['A_Iliac_Ext_R', 'R_Ext_Iliac_A']
# ['Artery', 'Iliac', 'Pelvis']
# Anatomic
# 18806.0
# A_Iliac_Int_L
# ['L_Int_Iliac_A', 'A_Iliac_Int_L']
# ['Artery', 'Iliac', 'Pelvis']
# Anatomic
# 18810.0
# A_Iliac_Int_R
# ['R_Int_Iliac_A', 'A_Iliac_Int_R']
# ['Artery', 'Iliac', 'Pelvis']
# Anatomic
# 18809.0
# A_Iliac_L
# ['A_Iliac_L', 'L_Iliac_A']
# ['Artery', 'Iliac', 'Pelvis']
# Anatomic
# 14766.0
# A_Iliac_R
# ['A_Iliac_R', 'R_Iliac_A']
# ['Artery', 'Iliac', 'Pelvis']
# Anatomic
# 14765.0
# A_LAD
# ['A_LAD', 'LAD_A']
# ['Artery', 'LAD', 'Thorax']
# Anatomic
# 3862.0
# A_Mesenteric_I
# ['I_Mesenteric_A', 'A_Mesenteric_I']
# ['Artery', 'Mesenteric', 'Abdomen']
# Anatomic
# 14750.0
# A_Mesenteric_S
# ['S_Mesenteric_A', 'A_Mesenteric_S']
# ['Artery', 'Mesenteric', 'Abdomen']
# Anatomic
# 14749.0
# A_Pulmonary
# ['A_Pulmonary', 'Pulmonary_A']
# ['Artery', 'Pulmonary', 'Thorax']
# Anatomic
# 66326.0
# A_Subclavian
# ['Subclavian_A', 'A_Subclavian']
# ['Artery', 'Subclavian', 'Thorax']
# Anatomic
# 3951.0
# A_Subclavian_L
# ['A_Subclavian_L', 'L_Subclavian_A']
# ['Artery', 'Subclavian', 'Thorax']
# Anatomic
# 4694.0
# A_Subclavian_R
# ['R_Subclavian_A', 'A_Subclavian_R']
# ['Artery', 'Subclavian', 'Thorax']
# Anatomic
# 3953.0
# A_Vertebral
# ['Vertebral_A', 'A_Vertebral']
# ['Artery', 'Vertebral', 'Thorax']
# Anatomic
# 3956.0
# A_Vertebral_L
# ['A_Vertebral_L', 'L_Vertebral_A']
# ['Artery', 'Vertebral', 'Thorax']
# Anatomic
# 4066.0
# A_Vertebral_R
# ['A_Vertebral_R', 'R_Vertebral_A']
# ['Artery', 'Vertebral', 'Thorax']
# Anatomic
# 3958.0
# Acetabulum_L
# ['L_Acetabulum', 'Acetabulum_L']
# ['Bone', 'Pelvic', 'Pelvis']
# Anatomic
# 16599.0
# Acetabulum_R
# ['Acetabulum_R', 'R_Acetabulum']
# ['Bone', 'Pelvic', 'Pelvis']
# Anatomic
# 16598.0
# Acetabulums
# ['Acetabulums']
# ['Bone', 'Pelvic', 'Pelvis']
# Anatomic
# 16579.0
# AirWay_Dist
# ['Dist_AirWay', 'AirWay_Dist']
# ['Lung', nan, 'Thorax']
# Anatomic
# nan
# AirWay_Prox
# ['Prox_AirWay', 'AirWay_Prox']
# ['Lung', nan, 'Thorax']
# Anatomic
# nan
# Anus
# ['Anus']
# ['Bowel', 'Anus', 'Pelvis']
# Anatomic
# 15711.0
# Appendix
# ['Appendix']
# ['Bowel', 'Appendix', 'Abdomen']
# Anatomic
# 14542.0
# Arytenoid
# ['Arytenoid']
# ['Cartilage', 'Arytenoid', 'Head and Neck']
# Anatomic
# 55109.0
# Arytenoid_L
# ['Arytenoid_L', 'L_Arytenoid']
# ['Cartilage', 'Arytenoid', 'Head and Neck']
# Anatomic
# 55114.0
# Arytenoid_R
# ['R_Arytenoid', 'Arytenoid_R']
# ['Cartilage', 'Arytenoid', 'Head and Neck']
# Anatomic
# 55113.0
# Atrium
# ['Atrium']
# ['Heart', 'Atrium', 'Thorax']
# Anatomic
# 7099.0
# Atrium_L
# ['L_Atrium', 'Atrium_L']
# ['Heart', 'Atrium', 'Thorax']
# Anatomic
# 7097.0
# Atrium_R
# ['Atrium_R', 'R_Atrium']
# ['Heart', 'Atrium', 'Thorax']
# Anatomic
# 7096.0
# Bag_Bowel
# ['Bag_Bowel', 'Bowel_Bag']
# ['Bowel', nan, 'Abdomen']
# Non_Anatomic
# nan
# Bag_Ostomy
# ['Bag_Ostomy', 'Ostomy_Bag']
# ['Devices', nan, 'Body']
# Non_Anatomic
# nan
# BileDuct_Common
# ['Common_BileDuct', 'BileDuct_Common']
# ['Bowel', 'Bile', 'Abdomen']
# Anatomic
# 14667.0
# Bladder
# ['Bladder']
# ['Bladder', nan, 'Pelvis']
# Anatomic
# 15900.0
# Bladder_Wall
# ['Bladder_Wall']
# ['Bladder', nan, 'Pelvis']
# Anatomic
# 15902.0
# Bladder-CTV
# ['Bladder-CTV']
# ['Bladder', nan, 'Pelvis']
# Derived
# nan
# Body
# ['Body']
# ['Body', nan, 'Body']
# Anatomic
# 256135.0
# Body-PTV
# ['Body-PTV']
# ['Body', nan, 'Body']
# Derived
# nan
# Bolus
# ['Bolus']
# ['Bolus', nan, 'Body']
# Non_Anatomic
# nan
# Bolus_xxmm
# ['Bolus_xxmm', 'xxmm_Bolus']
# ['Bolus', nan, 'Body']
# Non_Anatomic
# nan
# Bone
# ['Bone']
# ['Bone', nan, 'Body']
# Anatomic
# 30317.0
# Bone_Ethmoid
# ['Bone_Ethmoid', 'Ethmoid_Bone']
# ['Bone', 'Ethmoid', 'Head and Neck']
# Anatomic
# 52740.0
# Bone_Frontal
# ['Frontal_Bone', 'Bone_Frontal']
# ['Bone', 'Frontal', 'Head and Neck']
# Anatomic
# 52734.0
# Bone_Hyoid
# ['Hyoid_Bone', 'Bone_Hyoid']
# ['Bone', 'Hyoid', 'Head and Neck']
# Anatomic
# 52749.0
# Bone_Ilium
# ['Bone_Ilium', 'Ilium_Bone']
# ['Bone', 'Ilium', 'Pelvis']
# Anatomic
# 42832.0
# Bone_Ilium_L
# ['L_Ilium_Bone', 'Bone_Ilium_L']
# ['Bone', 'Ilium', 'Pelvis']
# Anatomic
# 16591.0
# Bone_Ilium_R
# ['Bone_Ilium_R', 'R_Ilium_Bone']
# ['Bone', 'Ilium', 'Pelvis']
# Anatomic
# 16590.0
# Bone_Incus
# ['Bone_Incus', 'Incus_Bone']
# ['Ear', 'Incus', 'Head and Neck']
# Anatomic
# 52752.0
# Bone_Incus_L
# ['Bone_Incus_L', 'L_Incus_Bone']
# ['Ear', 'Incus', 'Head and Neck']
# Anatomic
# 74051.0
# Bone_Incus_R
# ['Bone_Incus_R', 'R_Incus_Bone']
# ['Ear', 'Incus', 'Head and Neck']
# Anatomic
# 74050.0
# Bone_Ischium_L
# ['L_Ischium_Bone', 'Bone_Ischium_L']
# ['Bone', 'Ischium', 'Pelvis']
# Anatomic
# 16594.0
# Bone_Ischium_R
# ['Bone_Ischium_R', 'R_Ischium_Bone']
# ['Bone', 'Ischium', 'Pelvis']
# Anatomic
# 16593.0
# Bone_Lacrimal
# ['Lacrimal_Bone', 'Bone_Lacrimal']
# ['Bone', 'Lacrimal', 'Head and Neck']
# Anatomic
# 52741.0
# Bone_Lacrimal_L
# ['Bone_Lacrimal_L', 'L_Lacrimal_Bone']
# ['Bone', 'Lacrimal', 'Head and Neck']
# Anatomic
# 53646.0
# Bone_Lacrimal_R
# ['R_Lacrimal_Bone', 'Bone_Lacrimal_R']
# ['Bone', 'Lacrimal', 'Head and Neck']
# Anatomic
# 53645.0
# Bone_Mandible
# ['Mandible_Bone', 'Bone_Mandible']
# ['Bone', 'Mandible', 'Head and Neck']
# Anatomic
# 52748.0
# Bone_Mastoid
# ['Mastoid_Bone', 'Bone_Mastoid']
# ['Bone', 'Mastoid', 'Head and Neck']
# Anatomic
# 52872.0
# Bone_Mastoid_L
# ['Bone_Mastoid_L', 'L_Mastoid_Bone']
# ['Bone', 'Mastoid', 'Head and Neck']
# Anatomic
# 52874.0
# Bone_Mastoid_R
# ['Bone_Mastoid_R', 'R_Mastoid_Bone']
# ['Bone', 'Mastoid', 'Head and Neck']
# Anatomic
# 52873.0
# Bone_Nasal
# ['Nasal_Bone', 'Bone_Nasal']
# ['Bone', 'Nasal', 'Head and Neck']
# Anatomic
# 52745.0
# Bone_Nasal_L
# ['L_Nasal_Bone', 'Bone_Nasal_L']
# ['Bone', 'Nasal', 'Head and Neck']
# Anatomic
# 53648.0
# Bone_Nasal_R
# ['Bone_Nasal_R', 'R_Nasal_Bone']
# ['Bone', 'Nasal', 'Head and Neck']
# Anatomic
# 53647.0
# Bone_Occipital
# ['Occipital_Bone', 'Bone_Occipital']
# ['Bone', 'Occipital  ', 'Head and Neck']
# Anatomic
# 52735.0
# Bone_Palatine
# ['Palatine_Bone', 'Bone_Palatine']
# ['Bone', 'Palatine', 'Head and Neck']
# Anatomic
# 52746.0
# Bone_Palatine_L
# ['L_Palatine_Bone', 'Bone_Palatine_L']
# ['Bone', 'Palatine', 'Head and Neck']
# Anatomic
# 53656.0
# Bone_Palatine_R
# ['Bone_Palatine_R', 'R_Palatine_Bone']
# ['Bone', 'Palatine', 'Head and Neck']
# Anatomic
# 53655.0
# Bone_Parietal
# ['Parietal_Bone', 'Bone_Parietal']
# ['Bone', 'Parietal', 'Head and Neck']
# Anatomic
# 9613.0
# Bone_Parietal_L
# ['Bone_Parietal_L', 'L_Parietal_Bone']
# ['Bone', 'Parietal', 'Head and Neck']
# Anatomic
# 52789.0
# Bone_Parietal_R
# ['Bone_Parietal_R', 'R_Parietal_Bone']
# ['Bone', 'Parietal', 'Head and Neck']
# Anatomic
# 52788.0
# Bone_Pelvic
# ['Bone_Pelvic', 'Pelvic_Bone']
# ['Bone', 'Pelvic', 'Pelvis']
# Anatomic
# 16580.0
# Bone_Pelvic_L
# ['L_Pelvic_Bone', 'Bone_Pelvic_L']
# ['Bone', 'Pelvic', 'Pelvis']
# Anatomic
# 20227.0
# Bone_Pelvic_R
# ['Bone_Pelvic_R', 'R_Pelvic_Bone']
# ['Bone', 'Pelvic', 'Pelvis']
# Anatomic
# 20226.0
# Bone_Sphenoid
# ['Bone_Sphenoid', 'Sphenoid_Bone']
# ['Bone', 'Sphenoid', 'Head and Neck']
# Anatomic
# 52736.0
# Bone_Temporal
# ['Temporal_Bone', 'Bone_Temporal']
# ['Bone', 'Temporal', 'Head and Neck']
# Anatomic
# 52737.0
# Bone_Temporal_L
# ['Bone_Temporal_L', 'L_Temporal_Bone']
# ['Bone', 'Temporal', 'Head and Neck']
# Anatomic
# 52739.0
# Bone_Temporal_R
# ['Bone_Temporal_R', 'R_Temporal_Bone']
# ['Brain', 'Temporal', 'Head and Neck']
# Anatomic
# 52738.0
# Bone_Zygomatic_L
# ['L_Zygomatic_Bone', 'Bone_Zygomatic_L']
# ['Bone', 'Zygomatic', 'Head and Neck']
# Anatomic
# 52893.0
# Bone_Zygomatic_R
# ['Bone_Zygomatic_R', 'R_Zygomatic_Bone']
# ['Bone', 'Zygomatic', 'Head and Neck']
# Anatomic
# 52892.0
# Bone_Zygomatics
# ['Bone_Zygomatics', 'Zygomatics_Bone']
# ['Bone', 'Zygomatic', 'Head and Neck']
# Anatomic
# 52747.0
# BoneMarrow
# ['BoneMarrow']
# ['Bone', 'Marrow', 'Body']
# Anatomic
# 9608.0
# BoneMarrow_Act
# ['Act_BoneMarrow', 'BoneMarrow_Act']
# ['Bone', 'Marrow', 'Body']
# Anatomic
# nan
# Boost
# ['Boost']
# ['Body', nan, 'Body']
# Non-Anatomic
# nan
# Bowel
# ['Bowel']
# ['Bowel', nan, 'Abdomen']
# Anatomic
# 7199.0
# Bowel_Large
# ['Large_Bowel', 'Bowel_Large']
# ['Bowel', 'Large', 'Pelvis']
# Anatomic
# 7201.0
# Bowel_Small
# ['Bowel_Small', 'Small_Bowel']
# ['Bowel', nan, 'Abdomen']
# Anatomic
# 7200.0
# BrachialPlex_L
# ['L_BrachialPlex', 'BrachialPlex_L']
# ['Nerve', 'Brachial', 'Thorax']
# Anatomic
# 45245.0
# BrachialPlex_R
# ['BrachialPlex_R', 'R_BrachialPlex']
# ['Nerve', 'Brachial', 'Thorax']
# Anatomic
# 45244.0
# BrachialPlexs
# ['BrachialPlexs']
# ['Nerve', 'Brachial', 'Thorax']
# Anatomic
# 5906.0
# Brain
# ['Brain']
# ['Brain', 'Brain', 'Head and Neck']
# Anatomic
# 50801.0
# Brain-CTV
# ['Brain-CTV']
# ['Brain', 'Brain', 'Head and Neck']
# Derived
# nan
# Brain-GTV
# ['Brain-GTV']
# ['Brain', 'Brain', 'Head and Neck']
# Derived
# nan
# Brain-PTV
# ['Brain-PTV']
# ['Brain', 'Brain', 'Head and Neck']
# Derived
# nan
# Brainstem
# ['Brainstem']
# ['Nerve', 'Brainstem', 'Head and Neck']
# Anatomic
# 79876.0
# Brainstem_Core
# ['Brainstem_Core', 'Core_Brainstem']
# ['Nerve', 'Brainstem', 'Head and Neck']
# Anatomic
# nan
# Brainstem_PRV
# ['PRV_Brainstem', 'Brainstem_PRV']
# ['Nerve', 'PRV', 'Head and Neck']
# PRV
# nan
# Brainstem_PRVxx
# ['Brainstem_PRVxx', 'PRVxx_Brainstem']
# ['Nerve', 'PRV', 'Head and Neck']
# PRV
# nan
# Brainstem_Surf
# ['Surf_Brainstem', 'Brainstem_Surf']
# ['Nerve', 'Brainstem', 'Head and Neck']
# Anatomic
# nan
# Breast_L
# ['Breast_L', 'L_Breast']
# ['Breast', nan, 'Thorax']
# Anatomic
# 321497.0
# Breast_R
# ['Breast_R', 'R_Breast']
# ['Breast', nan, 'Thorax']
# Anatomic
# 321496.0
# Breasts
# ['Breasts']
# ['Breast', nan, 'Thorax']
# Anatomic
# 268893.0
# Bronchus
# ['Bronchus']
# ['Lung', 'Bronchus', 'Thorax']
# Anatomic
# 26660.0
# Bronchus_L
# ['Bronchus_L', 'L_Bronchus']
# ['Lung', 'Bronchus', 'Thorax']
# Anatomic
# 26662.0
# Bronchus_Main
# ['Main_Bronchus', 'Bronchus_Main']
# ['Lung', 'Bronchus', 'Thorax']
# Anatomic
# 7405.0
# Bronchus_Main_L
# ['L_Main_Bronchus', 'Bronchus_Main_L']
# ['Lung', 'Bronchus', 'Thorax']
# Anatomic
# 7396.0
# Bronchus_Main_R
# ['Bronchus_Main_R', 'R_Main_Bronchus']
# ['Lung', 'Bronchus', 'Thorax']
# Anatomic
# 7395.0
# Bronchus_PRVxx
# ['Bronchus_PRVxx', 'PRVxx_Bronchus']
# ['Lung', 'Bronchus', 'Thorax']
# Anatomic
# nan
# Bronchus_R
# ['Bronchus_R', 'R_Bronchus']
# ['Lung', 'Bronchus', 'Thorax']
# Anatomic
# 26661.0
# Canal_Anal
# ['Anal_Canal', 'Canal_Anal']
# ['Bowel', 'Anus', 'Pelvis']
# Anatomic
# 15703.0
# Carina
# ['Carina']
# ['Carina', nan, 'Thorax']
# Anatomic
# 7465.0
# Cartlg_Thyroid
# ['Thyroid_Cartlg', 'Cartlg_Thyroid']
# ['Cartilage', 'Thyroid', 'Thorax']
# Anatomic
# 55099.0
# CaudaEquina
# ['CaudaEquina']
# ['Nerve', 'CaudaEquina', 'Pelvis']
# Anatomic
# 52590.0
# Cavernosum
# ['Cavernosum']
# ['Reproductive', nan, 'Pelvis']
# Anatomic
# 75189.0
# Cavity_Nasal
# ['Nasal_Cavity', 'Cavity_Nasal']
# ['Nose', 'Nasal', 'Head and Neck']
# Anatomic
# 54378.0
# Cavity_Oral
# ['Cavity_Oral', 'Oral_Cavity']
# ['Mouth', 'Oral Cavity', 'Head and Neck']
# Anatomic
# 20292.0
# Cecum
# ['Cecum']
# ['Bowel', nan, 'Abdomen']
# Anatomic
# 14541.0
# Cerebellum
# ['Cerebellum']
# ['Brain', 'Cerebellum', 'Head and Neck']
# Anatomic
# 67944.0
# Cerebrum
# ['Cerebrum']
# ['Brain', 'Cerebrum', 'Head and Neck']
# Anatomic
# 62000.0
# Cerebrum_L
# ['Cerebrum_L', 'L_Cerebrum']
# ['Brain', 'Cerebrum', 'Head and Neck']
# Anatomic
# 61819.0
# Cerebrum_R
# ['Cerebrum_R', 'R_Cerebrum']
# ['Brain', 'Cerebrum', 'Head and Neck']
# Anatomic
# 67292.0
# Cervix
# ['Cervix']
# ['Cervix', nan, 'Pelvis']
# Anatomic
# 17740.0
# Chestwall
# ['Chestwall']
# ['Chest wall', nan, 'Thorax']
# Anatomic
# 50060.0
# Chestwall_L
# ['L_Chestwall', 'Chestwall_L']
# ['Chest wall', nan, 'Thorax']
# Anatomic
# 25559.0
# Chestwall_R
# ['R_Chestwall', 'Chestwall_R']
# ['Chest wall', nan, 'Thorax']
# Anatomic
# 25558.0
# Cist_Pontine
# ['Pontine_Cist', 'Cist_Pontine']
# ['Brain', nan, 'Head and Neck']
# Anatomic
# 83719.0
# Cist_Suprasellar
# ['Suprasellar_Cist', 'Cist_Suprasellar']
# ['Brain', nan, 'Head and Neck']
# Anatomic
# nan
# Clavicle_L
# ['Clavicle_L', 'L_Clavicle']
# ['Bone', 'Clavicle', 'Thorax']
# Anatomic
# 13323.0
# Clavicle_R
# ['R_Clavicle', 'Clavicle_R']
# ['Bone', 'Clavicle', 'Thorax']
# Anatomic
# 13322.0
# CN_III
# ['CN_III', 'III_CN']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50864.0
# CN_III_L
# ['CN_III_L', 'L_III_CN']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50880.0
# CN_III_R
# ['CN_III_R', 'R_III_CN']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50879.0
# CN_IX
# ['IX_CN', 'CN_IX']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50870.0
# CN_IX_L
# ['CN_IX_L', 'L_IX_CN']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50892.0
# CN_IX_R
# ['CN_IX_R', 'R_IX_CN']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50870.0
# CN_V
# ['CN_V', 'V_CN']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50866.0
# CN_V_L
# ['CN_V_L', 'L_V_CN']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50885.0
# CN_V_R
# ['R_V_CN', 'CN_V_R']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50884.0
# CN_VI
# ['CN_VI', 'VI_CN']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50867.0
# CN_VI_L
# ['CN_VI_L', 'L_VI_CN']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50887.0
# CN_VI_R
# ['R_VI_CN', 'CN_VI_R']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50886.0
# CN_VII
# ['CN_VII', 'VII_CN']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50868.0
# CN_VII_L
# ['L_VII_CN', 'CN_VII_L']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50889.0
# CN_VII_R
# ['R_VII_CN', 'CN_VII_R']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50888.0
# CN_VIII
# ['VIII_CN', 'CN_VIII']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50869.0
# CN_VIII_L
# ['CN_VIII_L', 'L_VIII_CN']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50891.0
# CN_VIII_R
# ['R_VIII_CN', 'CN_VIII_R']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50890.0
# CN_XI
# ['CN_XI', 'XI_CN']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 6720.0
# CN_XI_L
# ['CN_XI_L', 'L_XI_CN']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50899.0
# CN_XI_R
# ['CN_XI_R', 'R_XI_CN']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50897.0
# CN_XII
# ['CN_XII', 'XII_CN']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50871.0
# CN_XII_L
# ['L_XII_CN', 'CN_XII_L']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50903.0
# CN_XII_R
# ['CN_XII_R', 'R_XII_CN']
# ['Nerve', 'Cranial', 'Head and Neck']
# Anatomic
# 50901.0
# Cochlea
# ['Cochlea']
# ['Ear', 'Cochlea', 'Head and Neck']
# Anatomic
# 60201.0
# Cochlea_L
# ['Cochlea_L', 'L_Cochlea']
# ['Ear', 'Cochlea', 'Head and Neck']
# Anatomic
# 60203.0
# Cochlea_R
# ['R_Cochlea', 'Cochlea_R']
# ['Ear', 'Cochlea', 'Head and Neck']
# Anatomic
# 60202.0
# Colon
# ['Colon']
# ['Bowel', 'Colon', 'Abdomen']
# Anatomic
# 14543.0
# Colon_Ascending
# ['Colon_Ascending', 'Ascending_Colon']
# ['Bowel', 'Colon', 'Abdomen']
# Anatomic
# 14545.0
# Colon_Decending
# ['Decending_Colon', 'Colon_Decending']
# ['Bowel', 'Colon', 'Abdomen']
# Anatomic
# 14547.0
# Colon_PTVxx
# ['PTVxx_Colon', 'Colon_PTVxx']
# ['Bowel', nan, 'Abdomen']
# Anatomic
# nan
# Colon_Sigmoid
# ['Colon_Sigmoid', 'Sigmoid_Colon']
# ['Bowel', 'Colon', 'Abdomen']
# Anatomic
# 14548.0
# Colon_Transverse
# ['Colon_Transverse', 'Transverse_Colon']
# ['Bowel', 'Colon', 'Abdomen']
# Anatomic
# 14546.0
# Cornea
# ['Cornea']
# ['Eye', 'Cornea', 'Head and Neck']
# Anatomic
# 58238.0
# Cornea_L
# ['Cornea_L', 'L_Cornea']
# ['Eye', 'Cornea', 'Head and Neck']
# Anatomic
# 58240.0
# Cornea_R
# ['R_Cornea', 'Cornea_R']
# ['Eye', 'Cornea', 'Head and Neck']
# Anatomic
# 58239.0
# CribriformPlate
# ['CribriformPlate']
# ['Bone', 'Skull', 'Head and Neck']
# Anatomic
# 52890.0
# Cricoid
# ['Cricoid']
# ['Cartilage', 'Cricoid', 'Head and Neck']
# Anatomic
# 9615.0
# Cricopharyngeus
# ['Cricopharyngeus']
# ['Pharynx', 'Constrictors', 'Head and Neck']
# Anatomic
# 46661.0
# CTV
# ['CTV']
# ['CTV', nan, 'Body']
# Target
# nan
# Dens
# ['Dens']
# ['Bone', 'Spine', 'Head and Neck']
# Anatomic
# 24043.0
# Diaphragm
# ['Diaphragm']
# ['Diaphragm', nan, 'Thorax']
# Anatomic
# 13295.0
# Duodenum
# ['Duodenum']
# ['Gut', nan, 'Abdomen']
# Anatomic
# 7206.0
# Ear_External_L
# ['Ear_External_L', 'L_External_Ear']
# ['Ear', 'External', 'Head and Neck']
# Anatomic
# 53644.0
# Ear_External_R
# ['Ear_External_R', 'R_External_Ear']
# ['Ear', 'External', 'Head and Neck']
# Anatomic
# 53643.0
# Ear_Externals
# ['Externals_Ear', 'Ear_Externals']
# ['Ear', 'External', 'Head and Neck']
# Anatomic
# 52781.0
# Ear_Internal_L
# ['Ear_Internal_L', 'L_Internal_Ear']
# ['Ear', 'Internal', 'Head and Neck']
# Anatomic
# 61021.0
# Ear_Internal_R
# ['Ear_Internal_R', 'R_Internal_Ear']
# ['Ear', 'Internal', 'Head and Neck']
# Anatomic
# 61020.0
# Ear_Internals
# ['Internals_Ear', 'Ear_Internals']
# ['Ear', 'Internal', 'Head and Neck']
# Anatomic
# 60909.0
# Ear_Middle
# ['Ear_Middle', 'Middle_Ear']
# ['Ear', 'Middle', 'Head and Neck']
# Anatomic
# 56513.0
# Ear_Middle_L
# ['Ear_Middle_L', 'L_Middle_Ear']
# ['Ear', 'Middle', 'Head and Neck']
# Anatomic
# 56515.0
# Ear_Middle_R
# ['Ear_Middle_R', 'R_Middle_Ear']
# ['Ear', 'Middle', 'Head and Neck']
# Anatomic
# 56514.0
# Edema
# ['Edema']
# ['Skin', nan, 'Body']
# Anatomic
# nan
# Elbow
# ['Elbow']
# ['Joint', nan, 'Limbs']
# Anatomic
# 24901.0
# Elbow_L
# ['L_Elbow', 'Elbow_L']
# ['Joint', nan, 'Limbs']
# Anatomic
# 24903.0
# Elbow_R
# ['R_Elbow', 'Elbow_R']
# ['Joint', nan, 'Limbs']
# Anatomic
# 24902.0
# E-PTV_Ev05_xxxx
# ['E-PTV_Ev05_xxxx']
# ['Body', nan, 'Body']
# Non-Anatomic
# nan
# E-PTV_xxxx
# ['E-PTV_xxxx']
# ['Derived', nan, 'Body']
# Non-Anatomic
# nan
# Esophagus
# ['Esophagus']
# ['Esophagus', nan, 'Thorax']
# Anatomic
# 7131.0
# Esophagus_I
# ['I_Esophagus', 'Esophagus_I']
# ['Esophagus', nan, 'Thorax']
# Anatomic
# 9397.0
# Esophagus_M
# ['M_Esophagus', 'Esophagus_M']
# ['Esophagus', nan, 'Thorax']
# Anatomic
# 9396.0
# Esophagus_NAdj
# ['Esophagus_NAdj', 'NAdj_Esophagus']
# ['Esophagus', nan, 'Thorax']
# Anatomic
# nan
# Esophagus_S
# ['Esophagus_S', 'S_Esophagus']
# ['Esophagus', nan, 'Thorax']
# Anatomic
# nan
# Eval
# ['Eval']
# ['Body', nan, 'Body']
# Non-Anatomic
# nan
# External
# ['External']
# ['Body', nan, 'Body']
# Anatomic
# nan
# Eye_L
# ['Eye_L', 'L_Eye']
# ['Eye', 'Eyeball', 'Head and Neck']
# Anatomic
# 12515.0
# Eye_R
# ['Eye_R', 'R_Eye']
# ['Eye', 'Eyeball', 'Head and Neck']
# Anatomic
# 12514.0
# Eyes
# ['Eyes']
# ['Eye', nan, 'Head and Neck']
# Anatomic
# 268861.0
# Femur_Base_L
# ['Femur_Base_L', 'L_Base_Femur']
# ['Bone', 'Femur', 'Pelvis']
# Anatomic
# 32846.0
# Femur_Base_R
# ['R_Base_Femur', 'Femur_Base_R']
# ['Bone', 'Femur', 'Pelvis']
# Anatomic
# 32845.0
# Femur_Head_L
# ['Femur_Head_L', 'L_Head_Femur']
# ['Bone', 'Femur', 'Pelvis']
# Anatomic
# 32843.0
# Femur_Head_R
# ['R_Head_Femur', 'Femur_Head_R']
# ['Bone', 'Femur', 'Pelvis']
# Anatomic
# 32842.0
# Femur_Joint_L
# ['L_Joint_Femur', 'Femur_Joint_L']
# ['Joint', 'Femur', 'Pelvis']
# Anatomic
# 35180.0
# Femur_Joint_R
# ['R_Joint_Femur', 'Femur_Joint_R']
# ['Joint', 'Femur', 'Pelvis']
# Anatomic
# 35179.0
# Femur_L
# ['L_Femur', 'Femur_L']
# ['Bone', 'Femur', 'Limb']
# Anatomic
# 24475.0
# Femur_Neck_L
# ['L_Neck_Femur', 'Femur_Neck_L']
# ['Bone', 'Femur', 'Pelvis']
# Anatomic
# 42386.0
# Femur_Neck_R
# ['Femur_Neck_R', 'R_Neck_Femur']
# ['Bone', 'Femur', 'Pelvis']
# Anatomic
# 42387.0
# Femur_R
# ['R_Femur', 'Femur_R']
# ['Bone', 'Femur', 'Limb']
# Anatomic
# 24474.0
# Femur_Shaft_L
# ['L_Shaft_Femur', 'Femur_Shaft_L']
# ['Bone', 'Femur', 'Pelvis']
# Anatomic
# 32849.0
# Femur_Shaft_R
# ['R_Shaft_Femur', 'Femur_Shaft_R']
# ['Bone', 'Femur', 'Pelvis']
# Anatomic
# 32848.0
# Femurs
# ['Femurs']
# ['Bone', 'Femur', 'Limb']
# Anatomic
# 9611.0
# Fibula
# ['Fibula']
# ['Bone', 'Fibula', 'Limbs']
# Anatomic
# 24479.0
# Fibula_L
# ['L_Fibula', 'Fibula_L']
# ['Bone', 'Fibula', 'Limbs']
# Anatomic
# 24481.0
# Fibula_R
# ['Fibula_R', 'R_Fibula']
# ['Bone', 'Fibula', 'Limbs']
# Anatomic
# 24480.0
# Foley
# ['Foley']
# ['Bladder', nan, 'Pelvis']
# Non-Anatomic
# nan
# Fossa_Jugular
# ['Jugular_Fossa', 'Fossa_Jugular']
# ['Bone', 'Fossa', 'Head and Neck']
# Anatomic
# 56429.0
# Fossa_Posterior
# ['Fossa_Posterior', 'Posterior_Fossa']
# ['Bone', 'Fossa', 'Head and Neck']
# Anatomic
# 54368.0
# Gallbladder
# ['Gallbladder']
# ['Gallbladder', nan, 'Pelvis']
# Anatomic
# 7202.0
# Genitals
# ['Genitals']
# ['Reproductive', nan, 'Pelvis']
# Anatomic
# 45643.0
# Glnd_Adrenal_L
# ['Glnd_Adrenal_L', 'L_Adrenal_Glnd']
# ['Gland', 'Adrenal', 'Thorax']
# Anatomic
# 15629.0
# Glnd_Adrenal_R
# ['R_Adrenal_Glnd', 'Glnd_Adrenal_R']
# ['Gland', 'Adrenal', 'Thorax']
# Anatomic
# 15630.0
# Glnd_Lacrimal
# ['Lacrimal_Glnd', 'Glnd_Lacrimal']
# ['Gland', 'Lacrimal', 'Head and Neck']
# Anatomic
# 59101.0
# Glnd_Lacrimal_L
# ['L_Lacrimal_Glnd', 'Glnd_Lacrimal_L']
# ['Gland', 'Lacrimal', 'Head and Neck']
# Anatomic
# 59103.0
# Glnd_Lacrimal_R
# ['R_Lacrimal_Glnd', 'Glnd_Lacrimal_R']
# ['Gland', 'Lacrimal', 'Head and Neck']
# Anatomic
# 59102.0
# Glnd_Parathyroid
# ['Glnd_Parathyroid', 'Parathyroid_Glnd']
# ['Gland', nan, 'Thorax']
# Anatomic
# 13890.0
# Glnd_Subling_L
# ['L_Subling_Glnd', 'Glnd_Subling_L']
# ['Gland', 'Sublingual', 'Head and Neck']
# Anatomic
# 59805.0
# Glnd_Subling_R
# ['Glnd_Subling_R', 'R_Subling_Glnd']
# ['Gland', 'Sublingual', 'Head and Neck']
# Anatomic
# 59804.0
# Glnd_Sublings
# ['Sublings_Glnd', 'Glnd_Sublings']
# ['Gland', 'Sublingual', 'Head and Neck']
# Anatomic
# 320440.0
# Glnd_Submand_L
# ['Glnd_Submand_L', 'L_Submand_Glnd']
# ['Gland', 'Submandibular', 'Head and Neck']
# Anatomic
# 59803.0
# Glnd_Submand_R
# ['Glnd_Submand_R', 'R_Submand_Glnd']
# ['Gland', 'Submandibular', 'Head and Neck']
# Anatomic
# 59802.0
# Glnd_Submands
# ['Submands_Glnd', 'Glnd_Submands']
# ['Gland', 'Submandibular', 'Head and Neck']
# Anatomic
# 320442.0
# Glnd_Thymus
# ['Thymus_Glnd', 'Glnd_Thymus']
# ['Gland', 'Thymus', 'Thorax']
# Anatomic
# 9607.0
# Glnd_Thyroid
# ['Glnd_Thyroid', 'Thyroid_Glnd']
# ['Gland', 'Thyroid', 'Thorax']
# Anatomic
# 9603.0
# Glottis
# ['Glottis']
# ['Glottis', nan, 'Head and Neck']
# Anatomic
# 55414.0
# GreatVes
# ['GreatVes']
# ['Heart', nan, 'Thorax']
# Anatomic
# nan
# GreatVes_NAdj
# ['NAdj_GreatVes', 'GreatVes_NAdj']
# ['Heart', nan, 'Thorax']
# Anatomic
# nan
# GrowthPlate_L
# ['L_GrowthPlate', 'GrowthPlate_L']
# ['Bone', nan, 'Body']
# Anatomic
# nan
# GrowthPlate_R
# ['R_GrowthPlate', 'GrowthPlate_R']
# ['Bone', nan, 'Body']
# Anatomic
# nan
# GTV
# ['GTV']
# ['GTV', nan, 'Body']
# Target
# nan
# Hardpalate
# ['Hardpalate']
# ['Head', 'Mouth', 'Head and Neck']
# Anatomic
# 55023.0
# Heart
# ['Heart']
# ['Heart', nan, 'Thorax']
# Anatomic
# 7088.0
# Hemisphere_L
# ['L_Hemisphere', 'Hemisphere_L']
# ['Brain', 'Hemisphere', 'Head and Neck']
# Anatomic
# 61819.0
# Hemisphere_R
# ['Hemisphere_R', 'R_Hemisphere']
# ['Brain', 'Hemisphere', 'Head and Neck']
# Anatomic
# 67292.0
# Hemispheres
# ['Hemispheres']
# ['Brain', 'Hemisphere', 'Head and Neck']
# Anatomic
# nan
# Hippocampi
# ['Hippocampi']
# ['Brain', 'Hippocampus', 'Head and Neck']
# Anatomic
# 275020.0
# Hippocampus_L
# ['L_Hippocampus', 'Hippocampus_L']
# ['Brain', 'Hippocampus', 'Head and Neck']
# Anatomic
# 275024.0
# Hippocampus_R
# ['Hippocampus_R', 'R_Hippocampus']
# ['Brain', 'Hippocampus', 'Head and Neck']
# Anatomic
# 275022.0
# Humerus_L
# ['L_Humerus', 'Humerus_L']
# ['Bone', 'Humerus', 'Limbs']
# Anatomic
# 23131.0
# Humerus_R
# ['R_Humerus', 'Humerus_R']
# ['Bone', 'Humerus', 'Limbs']
# Anatomic
# 23130.0
# Hypothalmus
# ['Hypothalmus']
# ['Brain', 'Hypothalamus', 'Head and Neck']
# Anatomic
# 62008.0
# Hypothalmus_PRV
# ['Hypothalmus_PRV', 'PRV_Hypothalmus']
# ['Brain', 'Hypothalamus', 'Head and Neck']
# PRV
# nan
# Hypothalmus_PRVx
# ['Hypothalmus_PRVx', 'PRVx_Hypothalmus']
# ['Brain', 'Hypothalamus', 'Head and Neck']
# PRV
# nan
# IDL
# ['IDL']
# ['Dose', nan, 'Body']
# Non-Anatomic
# nan
# Ileum
# ['Ileum']
# ['Gut', nan, 'Abdomen']
# Anatomic
# 7208.0
# ITV
# ['ITV']
# ['ITV', nan, 'Body']
# Target
# nan
# Jejunum
# ['Jejunum']
# ['Gut', 'Small Bowel', 'Abdomen']
# Anatomic
# 7207.0
# Jejunum_Ileum
# ['Jejunum_Ileum']
# ['Gut', nan, 'Abdomen']
# Anatomic
# nan
# Joint_Elbow
# ['Elbow_Joint', 'Joint_Elbow']
# ['Joint', nan, 'Limbs']
# Anatomic
# 35289.0
# Joint_Elbow_L
# ['Joint_Elbow_L', 'L_Elbow_Joint']
# ['Joint', nan, 'Limbs']
# Anatomic
# 35295.0
# Joint_Elbow_R
# ['R_Elbow_Joint', 'Joint_Elbow_R']
# ['Joint', nan, 'Limbs']
# Anatomic
# 35294.0
# Joint_Glenohum
# ['Glenohum_Joint', 'Joint_Glenohum']
# ['Joint', 'Small Bowel', 'Limbs']
# Anatomic
# 25912.0
# Joint_Glenohum_L
# ['L_Glenohum_Joint', 'Joint_Glenohum_L']
# ['Joint', 'Small Bowel', 'Limbs']
# Anatomic
# 25929.0
# Joint_Glenohum_R
# ['R_Glenohum_Joint', 'Joint_Glenohum_R']
# ['Joint', 'Glenohumeral', 'Limbs']
# Anatomic
# 25927.0
# Joint_Surface
# ['Joint_Surface', 'Surface_Joint']
# ['Joint', 'Glenohumeral', 'Body']
# Anatomic
# nan
# Joint_TM
# ['Joint_TM', 'TM_Joint']
# ['Joint', 'Glenohumeral', 'Head and Neck']
# Anatomic
# 54832.0
# Joint_TM_L
# ['L_TM_Joint', 'Joint_TM_L']
# ['Joint', 'Temperomandibular', 'Head and Neck']
# Anatomic
# 54834.0
# Joint_TM_R
# ['R_TM_Joint', 'Joint_TM_R']
# ['Joint', 'Temperomandibular', 'Head and Neck']
# Anatomic
# 54833.0
# Kidney_Cortex
# ['Kidney_Cortex', 'Cortex_Kidney']
# ['Urinary', 'Kidney', 'Abdomen']
# Anatomic
# 15581.0
# Kidney_Cortex_L
# ['L_Cortex_Kidney', 'Kidney_Cortex_L']
# ['Urinary', 'Kidney', 'Abdomen']
# Anatomic
# 15584.0
# Kidney_Cortex_R
# ['Kidney_Cortex_R', 'R_Cortex_Kidney']
# ['Urinary', 'Kidney', 'Abdomen']
# Anatomic
# 15583.0
# Kidney_Hilum_L
# ['L_Hilum_Kidney', 'Kidney_Hilum_L']
# ['Urinary', 'Kidney', 'Abdomen']
# Anatomic
# 15942.0
# Kidney_Hilum_R
# ['R_Hilum_Kidney', 'Kidney_Hilum_R']
# ['Urinary', 'Kidney', 'Abdomen']
# Anatomic
# 15941.0
# Kidney_Hilums
# ['Hilums_Kidney', 'Kidney_Hilums']
# ['Urinary', 'Kidney', 'Abdomen']
# Anatomic
# 15610.0
# Kidney_L
# ['Kidney_L', 'L_Kidney']
# ['Urinary', 'Kidney', 'Abdomen']
# Anatomic
# 7205.0
# Kidney_L-GTV
# ['Kidney_L-GTV', 'L_Kidney-GTV']
# ['Urinary', 'Kidney', 'Abdomen']
# Derived
# nan
# Kidney_Pelvis_L
# ['Kidney_Pelvis_L', 'L_Pelvis_Kidney']
# ['Urinary', 'Kidney', 'Abdomen']
# Anatomic
# 15579.0
# Kidney_Pelvis_R
# ['Kidney_Pelvis_R', 'R_Pelvis_Kidney']
# ['Urinary', 'Kidney', 'Abdomen']
# Anatomic
# 15578.0
# Kidney_R
# ['R_Kidney', 'Kidney_R']
# ['Urinary', 'Kidney', 'Abdomen']
# Anatomic
# 7204.0
# Kidney_R-GTV
# ['Kidney_R-GTV', 'R_Kidney-GTV']
# ['Urinary', 'Kidney', 'Abdomen']
# Derived
# nan
# Kidney-GTV
# ['Kidney-GTV']
# ['Urinary', 'Kidney', 'Abdomen']
# Derived
# nan
# Kidneys
# ['Kidneys']
# ['Urinary', 'Kidney', 'Abdomen']
# Anatomic
# 264815.0
# Knee
# ['Knee']
# ['Joint', nan, 'Limbs']
# Anatomic
# 24974.0
# Knee_L
# ['L_Knee', 'Knee_L']
# ['Joint', nan, 'Limbs']
# Anatomic
# 24978.0
# Knee_R
# ['Knee_R', 'R_Knee']
# ['Joint', nan, 'Limbs']
# Anatomic
# 24977.0
# Laryngl_Pharynx
# ['Laryngl_Pharynx', 'Pharynx_Laryngl']
# ['Tissue', 'Laryngeal pharynx', 'Head and Neck']
# Anatomic
# 54880.0
# Larynx
# ['Larynx']
# ['Larynx', nan, 'Head and Neck']
# Anatomic
# 55097.0
# Larynx_SG
# ['SG_Larynx', 'Larynx_SG']
# ['Larynx', nan, 'Head and Neck']
# Anatomic
# 55476.0
# Leads
# ['Leads']
# ['Devices', nan, 'Body']
# Non_Anatomic
# nan
# Lens
# ['Lens']
# ['Eye', 'Lens', 'Head and Neck']
# Anatomic
# 58241.0
# Lens_L
# ['Lens_L', 'L_Lens']
# ['Eye', 'Lens', 'Head and Neck']
# Anatomic
# 58243.0
# Lens_R
# ['R_Lens', 'Lens_R']
# ['Eye', 'Lens', 'Head and Neck']
# Anatomic
# 58242.0
# Lig_Hepatogastrc
# ['Lig_Hepatogastrc', 'Hepatogastrc_Lig']
# ['Ligament', 'Hepatogastric', 'Abdomen']
# Anatomic
# 16520.0
# Lips
# ['Lips']
# ['Feature', nan, 'Head and Neck']
# Anatomic
# 59815.0
# Liver
# ['Liver']
# ['Liver', nan, 'Abdomen']
# Anatomic
# 7197.0
# Liver-CTV
# ['Liver-CTV']
# ['Liver', nan, 'Abdomen']
# Derived
# nan
# Liver-GTV
# ['Liver-GTV']
# ['Liver', nan, 'Abdomen']
# Derived
# nan
# LN
# ['LN']
# ['Lymph Node', nan, 'Body']
# Anatomic
# 5034.0
# LN_Ax_Apical
# ['LN_Ax_Apical', 'Apical_Ax_LN']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 23394.0
# LN_Ax_Apical_L
# ['L_Apical_Ax_LN', 'LN_Ax_Apical_L']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 73265.0
# LN_Ax_Apical_R
# ['R_Apical_Ax_LN', 'LN_Ax_Apical_R']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 73264.0
# LN_Ax_Central_L
# ['LN_Ax_Central_L', 'L_Central_Ax_LN']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 73263.0
# LN_Ax_Central_R
# ['R_Central_Ax_LN', 'LN_Ax_Central_R']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 73262.0
# LN_Ax_Centrals
# ['Centrals_Ax_LN', 'LN_Ax_Centrals']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 233482.0
# LN_Ax_L
# ['LN_Ax_L', 'L_Ax_LN']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 73250.0
# LN_Ax_L1_L
# ['LN_Ax_L1_L', 'L_L1_Ax_LN']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 276001.0
# LN_Ax_L1_R
# ['R_L1_Ax_LN', 'LN_Ax_L1_R']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 275999.0
# LN_Ax_L2_L
# ['L_L2_Ax_LN', 'LN_Ax_L2_L']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 276005.0
# LN_Ax_L2_R
# ['R_L2_Ax_LN', 'LN_Ax_L2_R']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 276003.0
# LN_Ax_L3_L
# ['LN_Ax_L3_L', 'L_L3_Ax_LN']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 276009.0
# LN_Ax_L3_R
# ['LN_Ax_L3_R', 'R_L3_Ax_LN']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 276007.0
# LN_Ax_Lateral_L
# ['L_Lateral_Ax_LN', 'LN_Ax_Lateral_L']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 73256.0
# LN_Ax_Lateral_R
# ['R_Lateral_Ax_LN', 'LN_Ax_Lateral_R']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 73255.0
# LN_Ax_Laterals
# ['Laterals_Ax_LN', 'LN_Ax_Laterals']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 233458.0
# LN_Ax_Pectoral_L
# ['L_Pectoral_Ax_LN', 'LN_Ax_Pectoral_L']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 73253.0
# LN_Ax_Pectoral_R
# ['R_Pectoral_Ax_LN', 'LN_Ax_Pectoral_R']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 73252.0
# LN_Ax_Pectorals
# ['LN_Ax_Pectorals', 'Pectorals_Ax_LN']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 233446.0
# LN_Ax_R
# ['LN_Ax_R', 'R_Ax_LN']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 73249.0
# LN_Ax_Subscap_L
# ['L_Subscap_Ax_LN', 'LN_Ax_Subscap_L']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 73259.0
# LN_Ax_Subscap_R
# ['R_Subscap_Ax_LN', 'LN_Ax_Subscap_R']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 73258.0
# LN_Ax_Subscaps
# ['Subscaps_Ax_LN', 'LN_Ax_Subscaps']
# ['Lymph Node', 'Axillary', 'Thorax']
# Anatomic
# 233470.0
# LN_Brachioceph_L
# ['L_Brachioceph_LN', 'LN_Brachioceph_L']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 5946.0
# LN_Brachioceph_R
# ['R_Brachioceph_LN', 'LN_Brachioceph_R']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 5945.0
# LN_Brachiocephs
# ['Brachiocephs_LN', 'LN_Brachiocephs']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 5944.0
# LN_Bronchpulm_L
# ['LN_Bronchpulm_L', 'L_Bronchpulm_LN']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 5967.0
# LN_Bronchpulm_R
# ['R_Bronchpulm_LN', 'LN_Bronchpulm_R']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 5966.0
# LN_Bronchpulms
# ['Bronchpulms_LN', 'LN_Bronchpulms']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 5965.0
# LN_Diaphragmatic
# ['Diaphragmatic_LN', 'LN_Diaphragmatic']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 12773.0
# LN_Iliac_Ext_L
# ['L_Ext_Iliac_LN', 'LN_Iliac_Ext_L']
# ['Lymph Node', nan, 'Pelvis']
# Anatomic
# 229177.0
# LN_Iliac_Ext_R
# ['LN_Iliac_Ext_R', 'R_Ext_Iliac_LN']
# ['Lymph Node', nan, 'Pelvis']
# Anatomic
# 229177.0
# LN_Iliac_Int_L
# ['LN_Iliac_Int_L', 'L_Int_Iliac_LN']
# ['Lymph Node', nan, 'Pelvis']
# Anatomic
# 224275.0
# LN_Iliac_L
# ['LN_Iliac_L', 'L_Iliac_LN']
# ['Lymph Node', nan, 'Pelvis']
# Anatomic
# 224269.0
# LN_Iliac_R
# ['R_Iliac_LN', 'LN_Iliac_R']
# ['Lymph Node', nan, 'Pelvis']
# Anatomic
# 224269.0
# LN_IMN_L
# ['LN_IMN_L', 'L_IMN_LN']
# ['Lymph Node', 'Breast', 'Thorax']
# Anatomic
# 5934.0
# LN_IMN_R
# ['R_IMN_LN', 'LN_IMN_R']
# ['Lymph Node', 'Breast', 'Thorax']
# Anatomic
# 5933.0
# LN_IMNs
# ['LN_IMNs', 'IMNs_LN']
# ['Lymph Node', 'Breast', 'Thorax']
# Anatomic
# 5849.0
# LN_Inguinofem
# ['LN_Inguinofem', 'Inguinofem_LN']
# ['Lymph Node', nan, 'Pelvis']
# Anatomic
# 236337.0
# LN_Inguinofem_L
# ['L_Inguinofem_LN', 'LN_Inguinofem_L']
# ['Lymph Node', nan, 'Pelvis']
# Anatomic
# 236341.0
# LN_Inguinofem_R
# ['R_Inguinofem_LN', 'LN_Inguinofem_R']
# ['Lymph Node', nan, 'Pelvis']
# Anatomic
# 236339.0
# LN_Intercostals
# ['LN_Intercostals', 'Intercostals_LN']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 5932.0
# LN_L
# ['LN_L', 'L_LN']
# ['Lymph Node', 'Unspecified', 'Body']
# Anatomic
# nan
# LN_Ligamentarter
# ['LN_Ligamentarter', 'Ligamentarter_LN']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 74033.0
# LN_lliac_Int_R
# ['R_Int_Iliac_LN', 'LN_lliac_Int_R']
# ['Lymph Node', nan, 'Pelvis']
# Anatomic
# 224275.0
# LN_Mediastinals
# ['Mediastinals_LN', 'LN_Mediastinals']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 12774.0
# LN_Neck_IA_L
# ['L_IA_Neck_LN', 'LN_Neck_IA_L']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 235616.0
# LN_Neck_IA_R
# ['LN_Neck_IA_R', 'R_IA_Neck_LN']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 235614.0
# LN_Neck_IB_L
# ['L_IB_Neck_LN', 'LN_Neck_IB_L']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 232676.0
# LN_Neck_IB_R
# ['R_IB_Neck_LN', 'LN_Neck_IB_R']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 232673.0
# LN_Neck_II_L
# ['LN_Neck_II_L', 'L_II_Neck_LN']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 265660.0
# LN_Neck_II_R
# ['LN_Neck_II_R', 'R_II_Neck_LN']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 265658.0
# LN_Neck_IIA_L
# ['LN_Neck_IIA_L', 'L_IIA_Neck_LN']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 241975.0
# LN_Neck_IIA_R
# ['LN_Neck_IIA_R', 'R_IIA_Neck_LN']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 241973.0
# LN_Neck_IIB_L
# ['L_IIB_Neck_LN', 'LN_Neck_IIB_L']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 241979.0
# LN_Neck_IIB_R
# ['LN_Neck_IIB_R', 'R_IIB_Neck_LN']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 241977.0
# LN_Neck_III_L
# ['LN_Neck_III_L', 'L_III_Neck_LN']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 241953.0
# LN_Neck_III_R
# ['R_III_Neck_LN', 'LN_Neck_III_R']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 241951.0
# LN_Neck_IV_L
# ['LN_Neck_IV_L', 'L_IV_Neck_LN']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 241959.0
# LN_Neck_IV_R
# ['LN_Neck_IV_R', 'R_IV_Neck_LN']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 241957.0
# LN_Neck_V_L
# ['L_V_Neck_LN', 'LN_Neck_V_L']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 241965.0
# LN_Neck_V_R
# ['LN_Neck_V_R', 'R_V_Neck_LN']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 241963.0
# LN_Neck_VA_L
# ['L_VA_Neck_LN', 'LN_Neck_VA_L']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 265629.0
# LN_Neck_VA_R
# ['LN_Neck_VA_R', 'R_VA_Neck_LN']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 265626.0
# LN_Neck_VB_L
# ['LN_Neck_VB_L', 'L_VB_Neck_LN']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# nan
# LN_Neck_VB_R
# ['R_VB_Neck_LN', 'LN_Neck_VB_R']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# nan
# LN_Neck_VC_L
# ['L_VC_Neck_LN', 'LN_Neck_VC_L']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 232721.0
# LN_Neck_VC_R
# ['R_VC_Neck_LN', 'LN_Neck_VC_R']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 232719.0
# LN_Neck_VI_L
# ['LN_Neck_VI_L', 'L_VI_Neck_LN']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 241971.0
# LN_Neck_VI_R
# ['LN_Neck_VI_R', 'R_VI_Neck_LN']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# 241969.0
# LN_Neck_VII_L
# ['L_VII_Neck_LN', 'LN_Neck_VII_L']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# nan
# LN_Neck_VII_R
# ['R_VII_Neck_LN', 'LN_Neck_VII_R']
# ['Lymph Node', 'Neck Nodes', 'Head and Neck']
# Anatomic
# nan
# LN_Obturator_L
# ['L_Obturator_LN', 'LN_Obturator_L']
# ['Lymph Node', nan, 'Pelvis']
# Anatomic
# 16676.0
# LN_Obturator_R
# ['R_Obturator_LN', 'LN_Obturator_R']
# ['Lymph Node', nan, 'Pelvis']
# Anatomic
# 16676.0
# LN_Paraaortic
# ['Paraaortic_LN', 'LN_Paraaortic']
# ['Lymph Node', nan, 'Pelvis']
# Anatomic
# 223899.0
# LN_Paramammary_L
# ['LN_Paramammary_L', 'L_Paramammary_LN']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 232600.0
# LN_Paramammary_R
# ['LN_Paramammary_R', 'R_Paramammary_LN']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 232598.0
# LN_Paramammarys
# ['LN_Paramammarys', 'Paramammarys_LN']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 44313.0
# LN_Parasternal_L
# ['L_Parasternal_LN', 'LN_Parasternal_L']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 5934.0
# LN_Parasternal_R
# ['LN_Parasternal_R', 'R_Parasternal_LN']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 5933.0
# LN_Parasternals
# ['Parasternals_LN', 'LN_Parasternals']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 5849.0
# LN_Pelvic_L
# ['L_Pelvic_LN', 'LN_Pelvic_L']
# ['Lymph Node', nan, 'Pelvis']
# Anatomic
# nan
# LN_Pelvic_R
# ['LN_Pelvic_R', 'R_Pelvic_LN']
# ['Lymph Node', nan, 'Pelvis']
# Anatomic
# nan
# LN_Pelvics
# ['Pelvics_LN', 'LN_Pelvics']
# ['Lymph Node', nan, 'Pelvis']
# Anatomic
# nan
# LN_Portahepatis
# ['LN_Portahepatis', 'Portahepatis_LN']
# ['Lymph Node', 'Porta hepatis', 'Abdomen']
# Anatomic
# 15758.0
# LN_Presacral_L
# ['L_Presacral_LN', 'LN_Presacral_L']
# ['Lymph Node', nan, 'Pelvis']
# Anatomic
# 234280.0
# LN_Presacral_R
# ['LN_Presacral_R', 'R_Presacral_LN']
# ['Lymph Node', nan, 'Pelvis']
# Anatomic
# 234280.0
# LN_Pulmonary_L
# ['LN_Pulmonary_L', 'L_Pulmonary_LN']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 5970.0
# LN_Pulmonary_R
# ['LN_Pulmonary_R', 'R_Pulmonary_LN']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 5969.0
# LN_Pulmonarys
# ['LN_Pulmonarys', 'Pulmonarys_LN']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 5968.0
# LN_R
# ['LN_R', 'R_LN']
# ['Lymph Node', 'Unspecified', 'Body']
# Anatomic
# nan
# LN_Sclav_L
# ['L_Sclav_LN', 'LN_Sclav_L']
# ['Lymph Node', 'Breast', 'Body']
# Anatomic
# 232719.0
# LN_Sclav_R
# ['LN_Sclav_R', 'R_Sclav_LN']
# ['Lymph Node', 'Breast', 'Body']
# Anatomic
# 232721.0
# LN_Supmammary_L
# ['LN_Supmammary_L', 'L_Supmammary_LN']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 232604.0
# LN_Supmammary_R
# ['LN_Supmammary_R', 'R_Supmammary_LN']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 232602.0
# LN_Supmammarys
# ['Supmammarys_LN', 'LN_Supmammarys']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 12785.0
# LN_Trachbrnchs
# ['Trachbronchs_LN', 'LN_Trachbrnchs']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 5950.0
# LN_Trachbrnchs_L
# ['L_Trachbronchs_LN', 'LN_Trachbrnchs_L']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 5952.0
# LN_Trachbrnchs_R
# ['LN_Trachbrnchs_R', 'R_Trachbronchs_LN']
# ['Lymph Node', nan, 'Thorax']
# Anatomic
# 5951.0
# Lobe_Frontal
# ['Lobe_Frontal', 'Frontal_Lobe']
# ['Brain', 'Lobe', 'Head and Neck']
# Anatomic
# 61824.0
# Lobe_Frontal_L
# ['Lobe_Frontal_L', 'L_Frontal_Lobe']
# ['Brain', 'Lobe', 'Head and Neck']
# Anatomic
# 72970.0
# Lobe_Frontal_R
# ['Lobe_Frontal_R', 'R_Frontal_Lobe']
# ['Brain', 'Lobe', 'Head and Neck']
# Anatomic
# 72969.0
# Lobe_Occipital
# ['Lobe_Occipital', 'Occipital_Lobe']
# ['Brain', 'Occipital Lobe', 'Head and Neck']
# Anatomic
# 67325.0
# Lobe_Occipital_L
# ['Lobe_Occipital_L', 'L_Occipital_Lobe']
# ['Brain', 'Occipital Lobe', 'Head and Neck']
# Anatomic
# 72976.0
# Lobe_Occipital_R
# ['R_Occipital_Lobe', 'Lobe_Occipital_R']
# ['Brain', 'Occipital Lobe', 'Head and Neck']
# Anatomic
# 72975.0
# Lobe_Parietal
# ['Lobe_Parietal', 'Parietal_Lobe']
# ['Brain', 'Lobe', 'Head and Neck']
# Anatomic
# 61826.0
# Lobe_Parietal_L
# ['L_Parietal_Lobe', 'Lobe_Parietal_L']
# ['Brain', 'Lobe', 'Head and Neck']
# Anatomic
# 72974.0
# Lobe_Parietal_R
# ['Lobe_Parietal_R', 'R_Parietal_Lobe']
# ['Brain', 'Lobe', 'Head and Neck']
# Anatomic
# 72973.0
# Lobe_Temporal
# ['Lobe_Temporal', 'Temporal_Lobe']
# ['Brain', 'Temporal', 'Head and Neck']
# Anatomic
# 61825.0
# Lobe_Temporal_L
# ['Lobe_Temporal_L', 'L_Temporal_Lobe']
# ['Brain', 'Temporal', 'Head and Neck']
# Anatomic
# 72972.0
# Lobe_Temporal_R
# ['R_Temporal_Lobe', 'Lobe_Temporal_R']
# ['Brain', 'Temporal', 'Head and Neck']
# Anatomic
# 72971.0
# Lung_L
# ['Lung_L', 'L_Lung']
# ['Lung', nan, 'Thorax']
# Anatomic
# 7310.0
# Lung_LLL
# ['Lung_LLL', 'LLL_Lung']
# ['Lung', nan, 'Thorax']
# Anatomic
# 7371.0
# Lung_LUL
# ['LUL_Lung', 'Lung_LUL']
# ['Lung', nan, 'Thorax']
# Anatomic
# 7370.0
# Lung_R
# ['R_Lung', 'Lung_R']
# ['Lung', nan, 'Thorax']
# Anatomic
# 7309.0
# Lung_RLL
# ['Lung_RLL', 'RLL_Lung']
# ['Lung', nan, 'Thorax']
# Anatomic
# 7337.0
# Lung_RML
# ['Lung_RML', 'RML_Lung']
# ['Lung', nan, 'Thorax']
# Anatomic
# 7383.0
# Lung_RUL
# ['RUL_Lung', 'Lung_RUL']
# ['Lung', nan, 'Thorax']
# Anatomic
# 7333.0
# Lungs
# ['Lungs']
# ['Lung', nan, 'Thorax']
# Anatomic
# 68877.0
# Lungs-CTV
# ['Lungs-CTV']
# ['Lung', nan, 'Thorax']
# Derived
# nan
# Lungs-GTV
# ['Lungs-GTV']
# ['Lung', nan, 'Thorax']
# Derived
# nan
# Lungs-ITV
# ['Lungs-ITV']
# ['Lung', nan, 'Thorax']
# Derived
# nan
# Lungs-PTV
# ['Lungs-PTV']
# ['Lung', nan, 'Thorax']
# Derived
# nan
# Malleus
# ['Malleus']
# ['Bone', 'Ear', 'Head and Neck']
# Anatomic
# 52753.0
# Malleus_L
# ['L_Malleus', 'Malleus_L']
# ['Bone', 'Ear', 'Head and Neck']
# Anatomic
# 74053.0
# Malleus_R
# ['R_Malleus', 'Malleus_R']
# ['Bone', 'Ear', 'Head and Neck']
# Anatomic
# 74052.0
# Markers
# ['Markers']
# ['Devices', nan, 'Body']
# Non_Anatomic
# nan
# Maxilla
# ['Maxilla']
# ['Bone', 'Maxilla', 'Head and Neck']
# Anatomic
# 9711.0
# Maxilla_L
# ['L_Maxilla', 'Maxilla_L']
# ['Bone', 'Maxilla', 'Head and Neck']
# Anatomic
# 53650.0
# Maxilla_R
# ['Maxilla_R', 'R_Maxilla']
# ['Bone', 'Maxilla', 'Head and Neck']
# Anatomic
# 53649.0
# Mediastinum
# ['Mediastinum']
# ['Heart', nan, 'Thorax']
# Anatomic
# 9826.0
# Musc
# ['Musc']
# ['Muscle', nan, 'Body']
# Anatomic
# 30316.0
# Musc_Constrict
# ['Musc_Constrict', 'Constrict_Musc']
# ['Muscle', 'Constrictors', 'Head and Neck']
# Anatomic
# 46620.0
# Musc_Constrict_I
# ['I_Constrict_Musc', 'Musc_Constrict_I']
# ['Muscle', 'Constrictors', 'Head and Neck']
# Anatomic
# 46623.0
# Musc_Constrict_M
# ['M_Constrict_Musc', 'Musc_Constrict_M']
# ['Muscle', 'Constrictors', 'Head and Neck']
# Anatomic
# 46622.0
# Musc_Constrict_S
# ['Musc_Constrict_S', 'S_Constrict_Musc']
# ['Muscle', 'Constrictors', 'Head and Neck']
# Anatomic
# 46621.0
# Musc_Digastric_L
# ['L_Digastric_Musc', 'Musc_Digastric_L']
# ['Muscle', 'Digastric', 'Abdomen']
# Anatomic
# 46293.0
# Musc_Digastric_R
# ['Musc_Digastric_R', 'R_Digastric_Musc']
# ['Muscle', 'Digastric', 'Abdomen']
# Anatomic
# 46292.0
# Musc_Masseter
# ['Masseter_Musc', 'Musc_Masseter']
# ['Muscle', 'Masseter', 'Head and Neck']
# Anatomic
# 48996.0
# Musc_Masseter_L
# ['L_Masseter_Musc', 'Musc_Masseter_L']
# ['Muscle', 'Masseter', 'Head and Neck']
# Anatomic
# 48998.0
# Musc_Masseter_R
# ['Musc_Masseter_R', 'R_Masseter_Musc']
# ['Muscle', 'Masseter', 'Head and Neck']
# Anatomic
# 48997.0
# Musc_Platysma_L
# ['L_Platysma_Musc', 'Musc_Platysma_L']
# ['Muscle', 'Platysma', 'Head and Neck']
# Anatomic
# 45740.0
# Musc_Platysma_R
# ['R_Platysma_Musc', 'Musc_Platysma_R']
# ['Muscle', 'Platysma', 'Head and Neck']
# Anatomic
# 45739.0
# Musc_Pterygoid_L
# ['L_Pterygoid_Musc', 'Musc_Pterygoid_L']
# ['Muscle', 'Pterygoid', 'Head and Neck']
# Anatomic
# nan
# Musc_Pterygoid_R
# ['R_Pterygoid_Musc', 'Musc_Pterygoid_R']
# ['Muscle', 'Pterygoid', 'Head and Neck']
# Anatomic
# nan
# Musc_Sclmast_L
# ['L_Sclmast_Musc', 'Musc_Sclmast_L']
# ['Muscle', 'Sternocleidomastoid', 'Head and Neck']
# Anatomic
# 13409.0
# Musc_Sclmast_R
# ['R_Sclmast_Musc', 'Musc_Sclmast_R']
# ['Muscle', 'Sternocleidomastoid', 'Head and Neck']
# Anatomic
# 13408.0
# Musc_Temporal_L
# ['L_Temporal_Musc', 'Musc_Temporal_L']
# ['Muscle', 'Temporal', 'Head and Neck']
# Anatomic
# 49008.0
# Musc_Temporal_R
# ['Musc_Temporal_R', 'R_Temporal_Musc']
# ['Muscle', 'Temporal', 'Head and Neck']
# Anatomic
# 49007.0
# Nasalconcha_LI
# ['Nasalconcha_LI', 'LI_Nasalconcha']
# ['Nose', 'Nasal', 'Head and Neck']
# Anatomic
# 54738.0
# Nasalconcha_RI
# ['Nasalconcha_RI', 'RI_Nasalconcha']
# ['Nose', 'Nasal', 'Head and Neck']
# Anatomic
# 54737.0
# Nasopharynx
# ['Nasopharynx']
# ['Nose', 'Nasal', 'Head and Neck']
# Anatomic
# 54878.0
# Nose
# ['Nose']
# ['Nose', 'Nasal', 'Head and Neck']
# Anatomic
# 46472.0
# Nrv_Peripheral
# ['Nrv_Peripheral', 'Peripheral_Nrv']
# ['Nerve', nan, 'Body']
# Anatomic
# nan
# Nrv_Root
# ['Nrv_Root', 'Root_Nrv']
# ['Nerve', nan, 'Body']
# Anatomic
# 5981.0
# OpticChiasm
# ['OpticChiasm']
# ['Nerve', 'Optic', 'Head and Neck']
# Anatomic
# 62045.0
# OpticChiasm_PRV
# ['OpticChiasm_PRV', 'PRV_OpticChiasm']
# ['Nerve', 'Optic', 'Head and Neck']
# PRV
# nan
# OpticChiasm_PRVx
# ['OpticChiasm_PRVx', 'PRVx_OpticChiasm']
# ['Nerve', 'Optic', 'Head and Neck']
# PRV
# nan
# OpticNrv
# ['OpticNrv']
# ['Nerve', 'Optic', 'Head and Neck']
# Anatomic
# 50863.0
# OpticNrv_L
# ['L_OpticNrv', 'OpticNrv_L']
# ['Nerve', 'Optic', 'Head and Neck']
# Anatomic
# 50878.0
# OpticNrv_PRV
# ['OpticNrv_PRV', 'PRV_OpticNrv']
# ['Nerve', 'Optic', 'Head and Neck']
# PRV
# nan
# OpticNrv_PRV_L
# ['L_PRV_OpticNrv', 'OpticNrv_PRV_L']
# ['Nerve', 'Optic', 'Head and Neck']
# PRV
# nan
# OpticNrv_PRV_R
# ['R_PRV_OpticNrv', 'OpticNrv_PRV_R']
# ['Nerve', 'Optic', 'Head and Neck']
# PRV
# nan
# OpticNrv_PRVxx_L
# ['OpticNrv_PRVxx_L', 'L_PRVxx_OpticNrv']
# ['Nerve', 'Optic', 'Head and Neck']
# PRV
# nan
# OpticNrv_PRVxx_R
# ['R_PRVxx_OpticNrv', 'OpticNrv_PRVxx_R']
# ['Nerve', 'Optic', 'Head and Neck']
# PRV
# nan
# OpticNrv_R
# ['R_OpticNrv', 'OpticNrv_R']
# ['Nerve', 'Optic', 'Head and Neck']
# Anatomic
# 50875.0
# Orbit_L
# ['L_Orbit', 'Orbit_L']
# ['Eye', 'Orbit', 'Head and Neck']
# Anatomic
# 54668.0
# Orbit_R
# ['Orbit_R', 'R_Orbit']
# ['Eye', 'Orbit', 'Head and Neck']
# Anatomic
# 54667.0
# Oropharynx
# ['Oropharynx']
# ['Throat', 'Oropharynx', 'Head and Neck']
# Anatomic
# 54879.0
# Ovaries
# ['Ovaries']
# ['Reproductive', nan, 'Pelvis']
# Anatomic
# 7409.0
# Ovary_L
# ['Ovary_L', 'L_Ovary']
# ['Reproductive', nan, 'Pelvis']
# Anatomic
# 7214.0
# Ovary_R
# ['Ovary_R', 'R_Ovary']
# ['Reproductive', nan, 'Pelvis']
# Anatomic
# 7213.0
# Pacemaker
# ['Pacemaker']
# ['Devices', nan, 'Thorax']
# Non_Anatomic
# nan
# Palate_Soft
# ['Soft_Palate', 'Palate_Soft']
# ['Muscle', 'Soft Palate', 'Head and Neck']
# Anatomic
# 55021.0
# PancJejuno
# ['PancJejuno']
# ['Gut', nan, 'Abdomen']
# Surgical
# nan
# Pancreas
# ['Pancreas']
# ['Gland', 'Pancreas', 'Abdomen']
# Anatomic
# 7198.0
# Pancreas_Head
# ['Head_Pancreas', 'Pancreas_Head']
# ['Gland', 'Pancreas', 'Abdomen']
# Anatomic
# 10468.0
# Pancreas_Tail
# ['Tail_Pancreas', 'Pancreas_Tail']
# ['Gland', 'Pancreas', 'Abdomen']
# Anatomic
# 14519.0
# Parametrium
# ['Parametrium']
# ['Reproductive', nan, 'Pelvis']
# Anatomic
# 77061.0
# Parotid_L
# ['L_Parotid', 'Parotid_L']
# ['Gland', 'Parotid', 'Head and Neck']
# Anatomic
# 59798.0
# Parotid_R
# ['R_Parotid', 'Parotid_R']
# ['Gland', 'Parotid', 'Head and Neck']
# Anatomic
# 59797.0
# Parotids
# ['Parotids']
# ['Gland', 'Parotid', 'Head and Neck']
# Anatomic
# 320436.0
# PenileBulb
# ['PenileBulb']
# ['Reproductive', nan, 'Pelvis']
# Anatomic
# 19614.0
# Penis
# ['Penis']
# ['Reproductive', nan, 'Pelvis']
# Anatomic
# 9707.0
# Pericardium
# ['Pericardium']
# ['Heart', 'Membrane', 'Thorax']
# Anatomic
# 9869.0
# Perineum
# ['Perineum']
# ['Perineum', nan, 'Pelvis']
# Anatomic
# 9579.0
# Peritoneum
# ['Peritoneum']
# ['Membrane', 'Peritoneum', 'Abdomen']
# Anatomic
# 9908.0
# Pharynx
# ['Pharynx']
# ['Throat', 'Pharynx', 'Head and Neck']
# Anatomic
# 46688.0
# Pineal
# ['Pineal']
# ['Gland', 'Pineal', 'Head and Neck']
# Anatomic
# 62033.0
# Pituitary
# ['Pituitary']
# ['Gland', 'Pituitary', 'Head and Neck']
# Anatomic
# 13889.0
# Pituitary_PRVxx
# ['PRVxx_Pituitary', 'Pituitary_PRVxx']
# ['Gland', 'Pituitary', 'Head and Neck']
# PRV
# nan
# Pons
# ['Pons']
# ['Brain', 'Brainstem', 'Head and Neck']
# Anatomic
# 67943.0
# Postop
# ['Postop']
# ['Surgery', nan, 'Body']
# Non_Anatomic
# nan
# Preop
# ['Preop']
# ['Surgery', nan, 'Body']
# Non_Anatomic
# nan
# Proc_Condyloid_L
# ['Proc_Condyloid_L', 'L_Condyloid_Proc']
# ['Bone', 'Mandible', 'Head and Neck']
# Anatomic
# 52838.0
# Proc_Condyloid_R
# ['Proc_Condyloid_R', 'R_Condyloid_Proc']
# ['Bone', 'Mandible', 'Head and Neck']
# Anatomic
# 52840.0
# Proc_Coronoid_L
# ['L_Coronoid_Proc', 'Proc_Coronoid_L']
# ['Bone', 'Mandible', 'Head and Neck']
# Anatomic
# 52835.0
# Proc_Coronoid_R
# ['Proc_Coronoid_R', 'R_Coronoid_Proc']
# ['Bone', 'Mandible', 'Head and Neck']
# Anatomic
# 52834.0
# Prostate
# ['Prostate']
# ['Gland', 'Prostate', 'Pelvis']
# Anatomic
# 9600.0
# ProstateBed
# ['ProstateBed']
# ['Surgery', 'Prostate', 'Pelvis']
# Anatomic
# nan
# Prosthesis
# ['Prosthesis']
# ['Surgery', nan, 'Body']
# Anatomic
# nan
# Pterygoid_Lat_L
# ['L_Lat_Pterygoid', 'Pterygoid_Lat_L']
# ['Muscle', 'Pterygoid', 'Head and Neck']
# Anatomic
# 49017.0
# Pterygoid_Lat_R
# ['R_Lat_Pterygoid', 'Pterygoid_Lat_R']
# ['Muscle', 'Pterygoid', 'Head and Neck']
# Anatomic
# 49016.0
# Pterygoid_Med_L
# ['L_Med_Pterygoid', 'Pterygoid_Med_L']
# ['Muscle', 'Pterygoid', 'Head and Neck']
# Anatomic
# 49013.0
# Pterygoid_Med_R
# ['Pterygoid_Med_R', 'R_Med_Pterygoid']
# ['Muscle', 'Pterygoid', 'Head and Neck']
# Anatomic
# 49012.0
# PTV
# ['PTV']
# ['PTV', nan, 'Body']
# Target
# nan
# PubicSymphys
# ['PubicSymphys']
# ['Bone', 'Pubic', 'Pelvis']
# Anatomic
# 16950.0
# PubicSymphys_L
# ['PubicSymphys_L', 'L_PubicSymphys']
# ['Bone', 'Pubic', 'Pelvis']
# Anatomic
# 16597.0
# PubicSymphys_R
# ['R_PubicSymphys', 'PubicSymphys_R']
# ['Bone', 'Pubic', 'Pelvis']
# Anatomic
# 16596.0
# Radius_L
# ['Radius_L', 'L_Radius']
# ['Bone', 'Radius', 'Limb']
# Anatomic
# 23465.0
# Radius_R
# ['R_Radius', 'Radius_R']
# ['Bone', 'Radius', 'Limb']
# Anatomic
# 23464.0
# Rectal_Wall
# ['Rectal_Wall']
# ['Rectum', nan, 'Pelvis']
# Anatomic
# 14626.0
# Rectum
# ['Rectum']
# ['Rectum', nan, 'Pelvis']
# Anatomic
# 14544.0
# Retina_L
# ['L_Retina', 'Retina_L']
# ['Eye', 'Retina', 'Head and Neck']
# Anatomic
# 58303.0
# Retina_PRVxx_L
# ['L_PRVxx_Retina', 'Retina_PRVxx_L']
# ['Eye', 'Retina', 'Head and Neck']
# PRV
# nan
# Retina_PRVxx_R
# ['Retina_PRVxx_R', 'R_PRVxx_Retina']
# ['Eye', 'Retina', 'Head and Neck']
# PRV
# nan
# Retina_R
# ['Retina_R', 'R_Retina']
# ['Eye', 'Retina', 'Head and Neck']
# Anatomic
# 58302.0
# Retinas
# ['Retinas']
# ['Eye', 'Retina', 'Head and Neck']
# Anatomic
# 58301.0
# Rib
# ['Rib']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 7574.0
# Rib01_L
# ['Rib01_L', 'L_Rib01']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 7987.0
# Rib01_R
# ['Rib01_R', 'R_Rib01']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 7857.0
# Rib02_L
# ['Rib02_L', 'L_Rib02']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8012.0
# Rib02_R
# ['Rib02_R', 'R_Rib02']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 7882.0
# Rib03_L
# ['Rib03_L', 'L_Rib03']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8039.0
# Rib03_R
# ['Rib03_R', 'R_Rib03']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 7909.0
# Rib04_L
# ['L_Rib04', 'Rib04_L']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8148.0
# Rib04_R
# ['Rib04_R', 'R_Rib04']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 7957.0
# Rib05_L
# ['Rib05_L', 'L_Rib05']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8093.0
# Rib05_R
# ['Rib05_R', 'R_Rib05']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8066.0
# Rib06_L
# ['Rib06_L', 'L_Rib06']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8202.0
# Rib06_R
# ['R_Rib06', 'Rib06_R']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8175.0
# Rib07_L
# ['Rib07_L', 'L_Rib07']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8256.0
# Rib07_R
# ['R_Rib07', 'Rib07_R']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8229.0
# Rib08_L
# ['L_Rib08', 'Rib08_L']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8310.0
# Rib08_R
# ['R_Rib08', 'Rib08_R']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8283.0
# Rib09_L
# ['L_Rib09', 'Rib09_L']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8391.0
# Rib09_R
# ['Rib09_R', 'R_Rib09']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8364.0
# Rib10_L
# ['L_Rib10', 'Rib10_L']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8472.0
# Rib10_R
# ['R_Rib10', 'Rib10_R']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8445.0
# Rib11_L
# ['L_Rib11', 'Rib11_L']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8532.0
# Rib11_R
# ['Rib11_R', 'R_Rib11']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8531.0
# Rib12_L
# ['Rib12_L', 'L_Rib12']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8534.0
# Rib12_R
# ['R_Rib12', 'Rib12_R']
# ['Bone', 'Rib', 'Thorax']
# Anatomic
# 8533.0
# SacralPlex
# ['SacralPlex']
# ['Nerve', 'Sacrum', 'Pelvis']
# Anatomic
# 5909.0
# Sacrum
# ['Sacrum']
# ['Bone', 'Spine', 'Pelvis']
# Anatomic
# 16202.0
# Scalp
# ['Scalp']
# ['Skin', nan, 'Head and Neck']
# Anatomic
# 46494.0
# Scapula_L
# ['Scapula_L', 'L_Scapula']
# ['Bone', 'Scapula', 'Thorax']
# Anatomic
# 13396.0
# Scapula_R
# ['R_Scapula', 'Scapula_R']
# ['Bone', 'Scapula', 'Thorax']
# Anatomic
# 13395.0
# Scar
# ['Scar']
# ['Skin', nan, 'Body']
# Anatomic
# nan
# Scar_Boost
# ['Scar_Boost', 'Boost_Scar']
# ['Skin', nan, 'Body']
# Anatomic
# nan
# Scrotum
# ['Scrotum']
# ['Skin', nan, 'Pelvis']
# Anatomic
# 18252.0
# SeminalVes
# ['SeminalVes']
# ['Gland', nan, 'Pelvis']
# Anatomic
# 19387.0
# SeminalVes_Dist
# ['SeminalVes_Dist', 'Dist_SeminalVes']
# ['Gland', nan, 'Pelvis']
# Anatomic
# nan
# SeminalVes_Prox
# ['SeminalVes_Prox', 'Prox_SeminalVes']
# ['Gland', nan, 'Pelvis']
# Anatomic
# nan
# Sinus_Ethmoid
# ['Sinus_Ethmoid', 'Ethmoid_Sinus']
# ['Sinus', 'Ethmoid', 'Head and Neck']
# Anatomic
# 84115.0
# Sinus_Frontal
# ['Frontal_Sinus', 'Sinus_Frontal']
# ['Brain', 'Sinus', 'Head and Neck']
# Anatomic
# 57417.0
# Sinus_Frontal_L
# ['L_Frontal_Sinus', 'Sinus_Frontal_L']
# ['Brain', 'Sinus', 'Head and Neck']
# Anatomic
# 57419.0
# Sinus_Frontal_R
# ['R_Frontal_Sinus', 'Sinus_Frontal_R']
# ['Brain', 'Sinus', 'Head and Neck']
# Anatomic
# 57418.0
# Sinus_Maxilry
# ['Sinus_Maxilry', 'Maxilry_Sinus']
# ['Sinus', 'Maxillary', 'Head and Neck']
# Anatomic
# 57715.0
# Sinus_Maxilry_L
# ['L_Maxilry_Sinus', 'Sinus_Maxilry_L']
# ['Sinus', 'Maxillary', 'Head and Neck']
# Anatomic
# 57717.0
# Sinus_Maxilry_R
# ['R_Maxilry_Sinus', 'Sinus_Maxilry_R']
# ['Sinus', 'Maxillary', 'Head and Neck']
# Anatomic
# 57716.0
# Sinus_Sphenoid
# ['Sphenoid_Sinus', 'Sinus_Sphenoid']
# ['Bone', 'Sphenoid', 'Head and Neck']
# Anatomic
# 54683.0
# Sinus_Sphenoid_L
# ['L_Sphenoid_Sinus', 'Sinus_Sphenoid_L']
# ['Bone', 'Sphenoid', 'Head and Neck']
# Anatomic
# 54708.0
# Sinus_Sphenoid_R
# ['R_Sphenoid_Sinus', 'Sinus_Sphenoid_R']
# ['Bone', 'Sphenoid', 'Head and Neck']
# Anatomic
# 54707.0
# Skin
# ['Skin']
# ['Skin', nan, 'Body']
# Anatomic
# 7163.0
# Skin_Perineum
# ['Skin_Perineum', 'Perineum_Skin']
# ['Skin', nan, 'Pelvis']
# Anatomic
# 20429.0
# Skin_Peritoneum
# ['Skin_Peritoneum', 'Peritoneum_Skin']
# ['Skin', nan, 'Abdomen']
# Anatomic
# nan
# Skull
# ['Skull']
# ['Bone', 'Skull', 'Head and Neck']
# Anatomic
# 46565.0
# Spc
# ['Spc']
# ['Space', nan, 'Body']
# Anatomic
# nan
# Spc_Bowel
# ['Spc_Bowel ', 'Bowel_Spc']
# ['Bowel', 'Space', 'Abdomen']
# Anatomic
# nan
# Spc_Bowel_Small
# ['Small_Bowel_Spc', 'Spc_Bowel_Small']
# ['Space', nan, 'Abdomen']
# Anatomic
# nan
# Spc_Retrophar_L
# ['L_Retrophar_Spc', 'Spc_Retrophar_L']
# ['Space', 'Retropharyngeal', 'Head and Neck']
# Anatomic
# nan
# Spc_Retrophar_R
# ['R_Retrophar_Spc', 'Spc_Retrophar_R']
# ['Space', 'Retropharyngeal', 'Head and Neck']
# Anatomic
# nan
# Spc_Retrophars
# ['Retrophars_Spc', 'Spc_Retrophars']
# ['Space', nan, 'Head and Neck']
# Anatomic
# 286702.0
# Spc_Retrosty
# ['Retrosty_Spc', 'Spc_Retrosty']
# ['Space', 'Retrostyloid', 'Head and Neck']
# Anatomic
# nan
# Spc_Retrosty_L
# ['Spc_Retrosty_L', 'L_Retrosty_Spc']
# ['Space', 'Retrostyloid', 'Head and Neck']
# Anatomic
# nan
# Spc_Retrosty_R
# ['Spc_Retrosty_R', 'R_Retrosty_Spc']
# ['Space', 'Retrostyloid', 'Head and Neck']
# Anatomic
# nan
# Spc_Supraclav_L
# ['Spc_Supraclav_L', 'L_Supraclav_Spc']
# ['Space', 'Supraclavicular', 'Thorax']
# Anatomic
# 45797.0
# Spc_Supraclav_R
# ['R_Supraclav_Spc', 'Spc_Supraclav_R']
# ['Space', 'Supraclavicular', 'Thorax']
# Anatomic
# 45796.0
# Sphincter_Anal
# ['Anal_Sphincter', 'Sphincter_Anal']
# ['Bowel', 'Anus', 'Pelvis']
# Anatomic
# 15710.0
# SpinalCanal
# ['SpinalCanal']
# ['Canal', 'Spinal Cord', 'Body']
# Anatomic
# 9680.0
# SpinalCanal_PRV
# ['SpinalCanal_PRV', 'PRV_SpinalCanal']
# ['PRV', 'Spinal Canal', 'Body']
# PRV
# nan
# SpinalCanal_PRVx
# ['PRVx_SpinalCanal', 'SpinalCanal_PRVx']
# ['PRV', 'Spinal Canal', 'Body']
# PRV
# nan
# SpinalCord
# ['SpinalCord']
# ['Nerve', 'Spinal Cord', 'Body']
# Anatomic
# 7647.0
# SpinalCord_Cerv
# ['SpinalCord_Cerv', 'Cerv_SpinalCord']
# ['Nerve', 'Spinal Cord', 'Head and Neck']
# Anatomic
# 71166.0
# SpinalCord_Lum
# ['Lum_SpinalCord', 'SpinalCord_Lum']
# ['Nerve', 'Spinal Cord', 'Abdomen']
# Anatomic
# 71168.0
# SpinalCord_PRV
# ['PRV_SpinalCord', 'SpinalCord_PRV']
# ['PRV', 'Spinal Cord', 'Body']
# PRV
# nan
# SpinalCord_PRVxx
# ['PRVxx_SpinalCord', 'SpinalCord_PRVxx']
# ['PRV', 'Spinal Cord', 'Body']
# PRV
# nan
# SpinalCord_Sac
# ['SpinalCord_Sac', 'Sac_SpinalCord']
# ['Nerve', 'Spinal Cord', 'Pelvis']
# Anatomic
# 256623.0
# SpinalCord_Thor
# ['SpinalCord_Thor', 'Thor_SpinalCord']
# ['Nerve', 'Spinal Cord', 'Thorax']
# Anatomic
# 71167.0
# Spleen
# ['Spleen']
# ['Lymph Node', 'Spleen', 'Abdomen']
# Anatomic
# 7196.0
# Spleen_Hilum
# ['Hilum_Spleen', 'Spleen_Hilum']
# ['Lymph Node', 'Spleen', 'Abdomen']
# Anatomic
# 15841.0
# Spongiosum
# ['Spongiosum']
# ['Reproductive', nan, 'Pelvis']
# Anatomic
# 19617.0
# Stapes
# ['Stapes']
# ['Ear', 'Stapes', 'Head and Neck']
# Anatomic
# 52751.0
# Stapes_L
# ['Stapes_L', 'L_Stapes']
# ['Ear', 'Stapes', 'Head and Neck']
# Anatomic
# 74049.0
# Stapes_R
# ['Stapes_R', 'R_Stapes']
# ['Ear', 'Stapes', 'Head and Neck']
# Anatomic
# 74048.0
# Stomach
# ['Stomach']
# ['Stomach', nan, 'Abdomen']
# Anatomic
# 7148.0
# Stomach_PRVxx
# ['Stomach_PRVxx', 'PRVxx_Stomach']
# ['Stomach', nan, 'Abdomen']
# PRV
# nan
# Strct
# ['Strct ', 'Strct']
# ['Body', nan, 'Body']
# Anatomic
# nan
# Strct_Suprapatel
# ['Suprapatel_Strct', 'Strct_Suprapatel']
# ['Joint', nan, 'Limb']
# Anatomic
# nan
# Surf_Eye
# ['Eye_Surf', 'Surf_Eye']
# ['Eye', nan, nan]
# Anatomic
# nan
# SurgicalBed
# ['SurgicalBed']
# ['Surgery', nan, 'Body']
# Anatomic
# nan
# Sys_Ventricular
# ['Ventricular_Sys', 'Sys_Ventricular']
# ['Brain', nan, 'Head and Neck']
# Anatomic
# 242787.0
# Tendon
# ['Tendon ', 'Tendon']
# ['Tendon', nan, 'Limb']
# Anatomic
# 9721.0
# Tendon_Quad
# ['Tendon_Quad', 'Quad_Tendon']
# ['Tendon', nan, 'Limb']
# Anatomic
# 46900.0
# Testis
# ['Testis']
# ['Reproductive', 'Testis', 'Pelvis']
# Anatomic
# 7210.0
# Testis_L
# ['Testis_L', 'L_Testis']
# ['Reproductive', 'Testis', 'Pelvis']
# Anatomic
# 7212.0
# Testis_R
# ['R_Testis', 'Testis_R']
# ['Reproductive', 'Testis', 'Pelvis']
# Anatomic
# 7211.0
# ThecalSac
# ['ThecalSac']
# ['Membrane', 'Thecal Sac', 'Body']
# Anatomic
# 83720.0
# Thoracic_Duct
# ['Thoracic_Duct', 'Duct_Thoracic']
# ['Duct', 'Thoracic', 'Thorax']
# Anatomic
# 5031.0
# Tongue
# ['Tongue']
# ['Mouth', 'Tongue', 'Head and Neck']
# Anatomic
# 54640.0
# Tongue_All
# ['Tongue_All', 'All_Tongue']
# ['Mouth', 'Tongue', 'Head and Neck']
# Anatomic
# nan
# Tongue_Base
# ['Tongue_Base', 'Base_Tongue']
# ['Mouth', 'Tongue', 'Head and Neck']
# Anatomic
# 54645.0
# Tongue_Base_L
# ['L_Base_Tongue', 'Tongue_Base_L']
# ['Mouth', 'Tongue', 'Head and Neck']
# Anatomic
# nan
# Tongue_Base_R
# ['Tongue_Base_R', 'R_Base_Tongue']
# ['Mouth', 'Tongue', 'Head and Neck']
# Anatomic
# nan
# Tongue_Oral
# ['Oral_Tongue', 'Tongue_Oral']
# ['Mouth', 'Tongue', 'Head and Neck']
# Anatomic
# 54644.0
# Tongue_Oral_L
# ['L_Oral_Tongue', 'Tongue_Oral_L']
# ['Mouth', 'Tongue', 'Head and Neck']
# Anatomic
# 281502.0
# Tongue_Oral_R
# ['Tongue_Oral_R', 'R_Oral_Tongue']
# ['Mouth', 'Tongue', 'Head and Neck']
# Anatomic
# 281500.0
# Tonsil
# ['Tonsil']
# ['Mouth', 'Tongue', 'Head and Neck']
# Anatomic
# 9609.0
# Trachea
# ['Trachea']
# ['Lung', 'Trachea', 'Thorax']
# Anatomic
# 7394.0
# Trachea_NAdj
# ['NAdj_Trachea', 'Trachea_NAdj']
# ['Lung', 'Trachea', 'Thorax']
# Anatomic
# nan
# TumorBed
# ['TumorBed']
# ['Surgery', nan, 'Body']
# Non_Anatomic
# nan
# Ureter_L
# ['L_Ureter', 'Ureter_L']
# ['Urinary', 'Ureter', 'Pelvis']
# Anatomic
# 17888.0
# Ureter_R
# ['R_Ureter', 'Ureter_R']
# ['Urinary', 'Ureter', 'Pelvis']
# Anatomic
# 17887.0
# UreterDivert
# ['UreterDivert']
# ['Urinary', 'Ureter', 'Pelvis']
# Anatomic
# nan
# Ureters
# ['Ureters']
# ['Urinary', 'Ureter', 'Pelvis']
# Anatomic
# 264814.0
# Urethra
# ['Urethra']
# ['Urinary', 'Urethra', 'Pelvis']
# Anatomic
# 19667.0
# Urethra_Prostatc
# ['Urethra_Prostatc', 'Prostatc_Urethra']
# ['Urinary', 'Urethra', 'Pelvis']
# Anatomic
# nan
# Uterus
# ['Uterus']
# ['Reproductive', 'Uterus', 'Pelvis']
# Anatomic
# 17558.0
# V_Azygos
# ['Azygos_V', 'V_Azygos']
# ['Vein', 'Azygos', 'Thorax']
# Anatomic
# 4838.0
# V_Brachioceph_L
# ['L_Brachioceph_V', 'V_Brachioceph_L']
# ['Vein', 'Brachiocephalic', 'Thorax']
# Anatomic
# 4761.0
# V_Brachioceph_R
# ['V_Brachioceph_R', 'R_Brachioceph_V']
# ['Vein', 'Brachiocephalic', 'Thorax']
# Anatomic
# 4751.0
# V_Iliac_Ext_L
# ['V_Iliac_Ext_L', 'L_Ext_Iliac_V']
# ['Vein', 'Iliac', 'Pelvis']
# Anatomic
# 18886.0
# V_Iliac_Ext_R
# ['R_Ext_Iliac_V', 'V_Iliac_Ext_R']
# ['Vein', 'Iliac', 'Pelvis']
# Anatomic
# 18885.0
# V_Iliac_Int_L
# ['L_Int_Iliac_V', 'V_Iliac_Int_L']
# ['Vein', 'Iliac', 'Pelvis']
# Anatomic
# 18810.0
# V_Iliac_Int_R
# ['R_Int_Iliac_V', 'V_Iliac_Int_R']
# ['Vein', 'Iliac', 'Pelvis']
# Anatomic
# 18809.0
# V_Iliac_L
# ['L_Iliac_V', 'V_Iliac_L']
# ['Vein', 'Iliac', 'Pelvis']
# Anatomic
# 21387.0
# V_Iliac_R
# ['R_Iliac_V', 'V_Iliac_R']
# ['Vein', 'Iliac', 'Pelvis']
# Anatomic
# 21388.0
# V_Jugular
# ['Jugular_V', 'V_Jugular']
# ['Vein', 'Jugular', 'Head and Neck']
# Anatomic
# nan
# V_Jugular_Ext_L
# ['L_Ext_Jugular_V', 'V_Jugular_Ext_L']
# ['Vein', 'Jugular', 'Head and Neck']
# Anatomic
# 13112.0
# V_Jugular_Ext_R
# ['R_Ext_Jugular_V', 'V_Jugular_Ext_R']
# ['Vein', 'Jugular', 'Head and Neck']
# Anatomic
# 13111.0
# V_Jugular_Int_L
# ['L_Int_Jugular_V', 'V_Jugular_Int_L']
# ['Vein', 'Jugular', 'Head and Neck']
# Anatomic
# 4754.0
# V_Jugular_Int_R
# ['R_Int_Jugular_V', 'V_Jugular_Int_R']
# ['Vein', 'Jugular', 'Head and Neck']
# Anatomic
# 4762.0
# V_Portal
# ['Portal_V', 'V_Portal']
# ['Vein', 'Portal', 'Abdomen']
# Anatomic
# 66645.0
# V_Pulmonary
# ['V_Pulmonary', 'Pulmonary_V']
# ['Vein', 'Pulmonary', 'Thorax']
# Anatomic
# 66643.0
# V_Subclavian_L
# ['V_Subclavian_L', 'L_Subclavian_V']
# ['Vein', 'Subclavian', 'Thorax']
# Anatomic
# 4763.0
# V_Subclavian_R
# ['V_Subclavian_R', 'R_Subclavian_V']
# ['Vein', 'Subclavian', 'Thorax']
# Anatomic
# 4755.0
# V_Subclavians
# ['Subclavians_V', 'V_Subclavians']
# ['Vein', 'Subclavian', 'Thorax']
# Anatomic
# 4725.0
# V_Venacava_I
# ['I_Venacava_V', 'V_Venacava_I']
# ['Vein', 'VenaCava', 'Thorax']
# Anatomic
# 10951.0
# V_Venacava_S
# ['S_Venacava_V', 'V_Venacava_S']
# ['Vein', 'VenaCava', 'Thorax']
# Anatomic
# 4720.0
# Vagina
# ['Vagina']
# ['Reproductive', 'Vagina', 'Pelvis']
# Anatomic
# 19949.0
# Vagina_Surf
# ['Vagina_Surf', 'Surf_Vagina']
# ['Reproductive', 'Vagina', 'Pelvis']
# Anatomic
# nan
# VaginalCuff
# ['VaginalCuff']
# ['Reproductive', 'Vagina', 'Pelvis']
# Anatomic
# nan
# Valve
# ['Valve']
# ['Valve', nan, 'Body']
# Anatomic
# nan
# Valve_Aortic
# ['Aortic_Valve', 'Valve_Aortic']
# ['Valve', 'Aorta', 'Thorax']
# Anatomic
# 7236.0
# Valve_Mitral
# ['Valve_Mitral', 'Mitral_Valve']
# ['Valve', 'Heart', 'Thorax']
# Anatomic
# 7235.0
# Valve_Pulmonic
# ['Valve_Pulmonic', 'Pulmonic_Valve']
# ['Valve', nan, 'Thorax']
# Anatomic
# 7246.0
# Valve_Tricuspid
# ['Tricuspid_Valve', 'Valve_Tricuspid']
# ['Valve', 'Heart', 'Thorax']
# Anatomic
# 7234.0
# VB
# ['VB']
# ['Bone', 'Vertebral Body', 'Body']
# Anatomic
# nan
# VB_C
# ['C_VB', 'VB_C']
# ['Bone', 'Vertebral Body', 'Head and Neck']
# Anatomic
# 72063.0
# VB_C1
# ['VB_C1', 'C1_VB']
# ['Bone', 'Vertebral Body', 'Head and Neck']
# Anatomic
# 12519.0
# VB_C2
# ['VB_C2', 'C2_VB']
# ['Bone', 'Vertebral Body', 'Head and Neck']
# Anatomic
# 12520.0
# VB_C3
# ['C3_VB', 'VB_C3']
# ['Bone', 'Vertebral Body', 'Head and Neck']
# Anatomic
# 12521.0
# VB_C4
# ['C4_VB', 'VB_C4']
# ['Bone', 'Vertebral Body', 'Head and Neck']
# Anatomic
# 12522.0
# VB_C5
# ['C5_VB', 'VB_C5']
# ['Bone', 'Vertebral Body', 'Head and Neck']
# Anatomic
# 12523.0
# VB_C6
# ['VB_C6', 'C6_VB']
# ['Bone', 'Vertebral Body', 'Head and Neck']
# Anatomic
# 12524.0
# VB_C7
# ['C7_VB', 'VB_C7']
# ['Bone', 'Vertebral Body', 'Head and Neck']
# Anatomic
# 12525.0
# VB_L
# ['L_VB', 'VB_L']
# ['Bone', 'Spine', 'Abdomen']
# Anatomic
# 72065.0
# VB_L1
# ['VB_L1', 'L1_VB']
# ['Bone', 'Spine', 'Abdomen']
# Anatomic
# 13072.0
# VB_L2
# ['L2_VB', 'VB_L2']
# ['Bone', 'Spine', 'Abdomen']
# Anatomic
# 13073.0
# VB_L3
# ['L3_VB', 'VB_L3']
# ['Bone', 'Spine', 'Abdomen']
# Anatomic
# 13074.0
# VB_L4
# ['VB_L4', 'L4_VB']
# ['Bone', 'Spine', 'Abdomen']
# Anatomic
# 13075.0
# VB_L5
# ['L5_VB', 'VB_L5']
# ['Bone', 'Spine', 'Abdomen']
# Anatomic
# 13076.0
# VB_S
# ['VB_S', 'S_VB']
# ['Bone', 'Spine', 'Pelvis']
# Anatomic
# 12526.0
# VB_S1
# ['S1_VB', 'VB_S1']
# ['Bone', 'Spine', 'Pelvis']
# Anatomic
# 13077.0
# VB_S2
# ['VB_S2', 'S2_VB']
# ['Bone', 'Spine', 'Pelvis']
# Anatomic
# 13078.0
# VB_S3
# ['VB_S3', 'S3_VB']
# ['Bone', 'Spine', 'Pelvis']
# Anatomic
# 13079.0
# VB_S4
# ['S4_VB', 'VB_S4']
# ['Bone', 'Spine', 'Pelvis']
# Anatomic
# 13080.0
# VB_S5
# ['VB_S5', 'S5_VB']
# ['Bone', 'Spine', 'Pelvis']
# Anatomic
# 13081.0
# VB_T
# ['VB_T', 'T_VB']
# ['Bone', 'Spine', 'Thorax']
# Anatomic
# 9139.0
# VB_T01
# ['VB_T01', 'T01_VB']
# ['Bone', 'Spine', 'Thorax']
# Anatomic
# 9165.0
# VB_T02
# ['T02_VB', 'VB_T02']
# ['Bone', 'Spine', 'Thorax']
# Anatomic
# 9187.0
# VB_T03
# ['VB_T03', 'T03_VB']
# ['Bone', 'Spine', 'Thorax']
# Anatomic
# 9209.0
# VB_T04
# ['T04_VB', 'VB_T04']
# ['Bone', 'Spine', 'Thorax']
# Anatomic
# 9248.0
# VB_T05
# ['VB_T05', 'T05_VB']
# ['Bone', 'Spine', 'Thorax']
# Anatomic
# 9922.0
# VB_T06
# ['T06_VB', 'VB_T06']
# ['Bone', 'Spine', 'Thorax']
# Anatomic
# 9945.0
# VB_T07
# ['T07_VB', 'VB_T07']
# ['Bone', 'Spine', 'Thorax']
# Anatomic
# 9968.0
# VB_T08
# ['T08_VB', 'VB_T08']
# ['Bone', 'Spine', 'Thorax']
# Anatomic
# 9991.0
# VB_T09
# ['T09_VB', 'VB_T09']
# ['Bone', 'Spine', 'Thorax']
# Anatomic
# 10014.0
# VB_T10
# ['T10_VB', 'VB_T10']
# ['Bone', 'Spine', 'Thorax']
# Anatomic
# 10037.0
# VB_T11
# ['VB_T11', 'T11_VB']
# ['Bone', 'Spine', 'Thorax']
# Anatomic
# 10059.0
# VB_T12
# ['T12_VB', 'VB_T12']
# ['Bone', 'Spine', 'Thorax']
# Anatomic
# 10081.0
# VBs
# ['VBs']
# ['Bone', 'Vertebral Body', 'Body']
# Anatomic
# 11945.0
# Ventricle
# ['Ventricle']
# ['Heart', 'Ventricle', 'Thorax']
# Anatomic
# 7100.0
# Ventricle_L
# ['Ventricle_L', 'L_Ventricle']
# ['Heart', 'Ventricle', 'Thorax']
# Anatomic
# 7101.0
# Ventricle_R
# ['Ventricle_R', 'R_Ventricle']
# ['Heart', 'Ventricle', 'Thorax']
# Anatomic
# 7098.0
# VocalCord_L
# ['VocalCord_L', 'L_VocalCord']
# ['Larynx', nan, 'Head and Neck']
# Anatomic
# 55459.0
# VocalCord_R
# ['VocalCord_R', 'R_VocalCord']
# ['Larynx', nan, 'Head and Neck']
# Anatomic
# 55458.0
# VocalCords
# ['VocalCords']
# ['Larynx', nan, 'Head and Neck']
# Anatomic
# 323919.0
# Vomer
# ['Vomer']
# ['Bone', 'Vomer', 'Head and Neck']
# Anatomic
# 9710.0
# Vulva
# ['Vulva']
# ['Reproductive', 'Vulva', 'Pelvis']
# Anatomic
# 20462.0
# Wall_Vagina
# ['Wall_Vagina', 'Vagina_Wall']
# ['Reproductive', 'Vagina', 'Pelvis']
# Anatomic
# 19971.0

# %%
harmonizer.roi_dict.keys()
# Out:
# dict_keys([' intestino tc1', ' paloma', '(D) Blad OL', '(D) Blad Opt', '(D) CD OL', '(D) CD OPT', '(D) LB OL', '(D) PRSV OL', '(D) PRSV OPT', '(D) PTV 70.2 OL', '(D) Rect Opt', '(D)Ptv 70.2 opt', '(PTV2-dig)-rct', '(ptv pelvis)', '(ptvopt-dig)-rec', '1', '10 Gy 2015', '100%buiten PTV2', '2', '2MARKUP_PTVA', '2OPT_Bladder', '2OPT_Bowel', '2OPT_Bowel+PTVA', '2OPT_PTVA', '2OPT_PTVA_BST', '2OPT_PTVA_BST2', '2OPT_PTVB', '2OPT_PTVB BST', '2OPT_PTVB_CTRL', '2OPT_Rectum', '2PTVA_Ring', '2PTVB', '2PTVexp', '2Prostate', '3', '3Reperi', '4', '4536.80cGy', '51.3gy', '5350.00cGy', '5350.00cGy_1', '62,51G_exPTV1', '62.51G_exPTV1', '6420.00cGy', '72.5%', '76', 'ABO', 'AJM Bowel', 'AJM bladder', 'AJM rectum', 'ALL_Targets_exp', 'ALLtarget', 'ALO_In_Vivo_PT', 'ANO', 'ANO TC1', 'ANO TC2', 'ANORETTO', 'ANOin', 'ANSA', 'ANSE', 'ANSE 0.5mm', 'ANSE INTESTINALI', 'ANT_In_Vivo_PT', 'APEX', 'ARIA', 'ARO_In_Vivo_PT', 'ARTEFACT', 'ARTIFACT', 'AVOID', 'A_inPTV1', 'Abdominalhoehle', 'AcqIsocenter', 'Acqua', 'Addbody', 'Adenop', 'Adenopatias', 'AllTarget', 'AllTargets', 'AnCa_exPTV1_3', 'AnCa_exPTV1c_3', 'AnCa_exPTV1fr18', 'AnCan+Rec', 'AnCan+Rec inPTV', 'AnCan+Rec noPTV', 'Anaal kanaal', 'Anal Canal', 'Anal Canal inPTV', 'Anal Canal noPTV', 'Anal canal', 'Anal canal inPTV', 'Anal canal noPTV', 'Anal+Rectum', 'AnalCanal', 'AnalCanal inPTV', 'AnalCanal noPTV', 'AnalCanal+Rectum', 'AnalCanal-PTV', 'AnalCanalInPTV', 'AnalCanalRectum', 'AnalSphincter', 'Anal_canal', 'Analcanal', 'Anca_inPTV1', 'Ano', 'Ano 1', 'Ano 2', 'Ano TAC 1', 'Ano TAC 2', 'Ano TC 1', 'Ano TC 2', 'Ano TC2', 'Ano tac 1', 'Ano tc 1', 'Ano tc 2', 'Ano tc 3', 'Ano tc 4', 'Ano tc1', 'Ano tc2', 'Anoretto', 'Ant_In_Vivo_PT', 'Anus', 'Anus (ant.)', 'Anus (ext.)', 'Anus (int.)', 'Anus (post.)', 'Apex', 'Artefact', 'Artefacts', 'Artefakte', 'Artefatti', 'Artifact', 'Artificial HIP', 'Avoidance', 'Avoidance 56', 'Avoidance 70', 'Avoidance 77', 'Avoidance0', 'Ax_lim', 'BLADDER', 'BLADDER MIN FILL', 'BLADDEROPT', 'BLADDEROPT2', 'BL_inPTV1c', 'BMILEO', 'BMILEO IN54', 'BMLS', 'BMLS IN54', 'BMPELVIS', 'BMPELVIS IN54', 'BMPELVIS IN74', 'BMS LS', 'BMS ileo', 'BM_ILEO', 'BM_LS', 'BM_PELVIS', 'BODY', 'BOOST', 'BOOst', 'BOWEL', 'BOWEL AND PTVB', 'BOWEL IN PTVA', 'BOWEL KVK', 'BOWEL2', 'BULBO', 'BULBO P', 'BULBO PENIENO', 'BaseDroite', 'BaseGauche', 'Bauchhöhle', 'Beacons', 'Becken', 'Becken 44Gy', 'Becken LAW', 'Becken/LAW', 'Becken_mod', 'Beckenknochen', 'Bl_exPTV1_3', 'Bl_exPTV1c_3', 'Bl_exPTV1fr18', 'Bl_inPTV1', 'Bl_inPTV1fr18', 'Bl_inPTV2', 'Blaas', 'Blaas Crop', 'Blaas noPTV', 'Blad_inPTV1', 'Bladd in PTV', 'Bladd&PTV', 'Bladder', 'Bladder CT', 'Bladder Crop', 'Bladder Eval', 'Bladder Liam', 'Bladder Opt', 'Bladder Opt 2', 'Bladder Opt2', 'Bladder Wall', 'Bladder avoid', 'Bladder avoid1', 'Bladder avoid2', 'Bladder correct', 'Bladder in PTV', 'Bladder noPTV', 'Bladder opt', 'Bladder opt1', 'Bladder wall', 'Bladder-PTV', 'BladderWall', 'Bladder_Inside', 'Bladder_PTV', 'Bladder_opt45Gy', 'Bladder_opt70.2G', 'Bladder_out', 'Bladder_yl', 'Bladdo', 'Blase', 'Blase MRT', 'Blase union', 'Blood vessels', 'Blood vessels2', 'Body', 'Body1', 'Bolsa colostom', 'Bolus Bag', 'Bones', 'Boost', 'Boost Loge', 'Bowel', 'Bowel 56', 'Bowel Bag', 'Bowel Bag noPTV', 'Bowel InPTV', 'Bowel JD', 'Bowel NoPTV', 'Bowel PTV', 'Bowel PTV70', 'Bowel and PTVA', 'Bowel and PTVB', 'Bowel bag', 'Bowel bag noPTV', 'Bowel in Loge', 'Bowel in PTV', 'Bowel in PTVA', 'Bowel in PTVB', 'Bowel in PTVN', 'Bowel in Pelvis', 'Bowel inPTV', 'Bowel noPTV', 'Bowel not', 'Bowel not Loge', 'Bowel not PTV', 'Bowel not Pelvis', 'Bowel-PTV56', 'Bowel1', 'BowelB-PTV_5600', 'BowelB-PTV_7700', 'BowelBAG', 'BowelBInPTV_5600', 'BowelBInPTV_7700', 'BowelBag', 'BowelBag Crop', 'BowelBag in PTV', 'BowelBag noPTV', 'BowelBag not PTV', 'BowelBag-PTV', 'BowelBag-Pelv_05', 'BowelBagInPTV', 'BowelBagInPTV56', 'BowelBagInPTV70', 'BowelBagInPTV_66', 'BowelBagInPTV_77', 'BowelBagInPTVt', 'BowelInPTV', 'BowelInPelvis', 'BowelNotPTV', 'BowelOPT', 'Bowel_Check', 'Bowelbag', ' ...

# %%
harmonizer.run_harmonization()
# Out:
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:302: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   self.harmonized_df_matches: pd.DataFrame = self.harmonized_df.applymap(self.match_method)  # type: ignore # noqa

# %%
harmonizer.harmonize_df_get_scores()

# %%
harmonizer.harmonized_df.to_csv('harmonized_df_scores.csv')

# %%
from harmonizer_gui import HarmonizerGUI

harmonizer_gui = HarmonizerGUI(harmonized_df.transpose())
harmonizer_gui.run()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17920\2899083627.py in ?()
#       1 from harmonizer_gui import HarmonizerGUI
#       2
# ----> 3 harmonizer_gui = HarmonizerGUI(harmonizer.harmonized_df.transpose())
#       4 harmonizer_gui.run()
#
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\harmonizer_gui.py in ?(self, harmonizer)
#      14         self.label.grid(column=0, row=0)
#      15
#      16         # Create a Combobox for input
#      17         self.input_text = ttk.Combobox(self.root, values=harmonized_df.columns.tolist())
# ---> 18         self.input_text.grid(column=1, row=0)
#      19
#      20         # Create a Spinbox to select the number of results
#      21         self.num_results = ttk.Spinbox(self.root, from_=1, to=100)
#
# c:\Users\wd982598\.virtualenvs\structure_harmonization-AfCjJfLJ\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'harmonized_df'
