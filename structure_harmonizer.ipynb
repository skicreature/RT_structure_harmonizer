# %%
import os
import fnmatch
import pydicom
from pydicom import dcmread
import numpy as np
import pandas as pd
from openpyxl import load_workbook
from fuzzywuzzy import fuzz
import re
from structure_harmonizer import StructureHarmonizer
import pathlib
#from structure_regex import generate_structure_name

# set the directory to search
# directory = '/pct_ids/users/wd982598/test_requite'
directory = pathlib.Path(r'C:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\test_requite')
output_file =r'structure_dictionary'
TG_263_file_path=pathlib.Path(r'C:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\TG263_Nomenclature_Worksheet_20170815.xls')
#directory = '/mnt/t/Batch_1/'

# Define the match quality threshold
threshold = 88

# Create an instance of StructureHarmonizer and call the harmonize_structures method
harmonizer = StructureHarmonizer(
    directory, 
    output_file, 
    TG_263_file_path, 
    threshold=threshold, 
    roi_json_path='json_roi_dict.json'
    )
# Out:
# c:\Users\wd982598\.virtualenvs\structure_harmonization-AfCjJfLJ\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
harmonizer.load_json_roi_dict(harmonizer.roi_json_path)

# %%
harmonizer.TG_263_df.head()
# Out:
#   Target Type Major Category   Minor Category Anatomic Group  N Characters  \
# 0    Anatomic         Artery            Aorta         Thorax             7
# 1    Anatomic         Artery            Aorta         Thorax            11
# 2    Anatomic         Artery  Brachiocephalic         Thorax            15
# 3    Anatomic         Artery          Carotid  Head and Neck             9
# 4    Anatomic         Artery          Carotid  Head and Neck            11
#
#   TG263-Primary Name TG-263-Reverse Order Name             Description  \
# 0            A_Aorta                   Aorta_A                   Aorta
# 1        A_Aorta_Asc               Asc_Aorta_A         Ascending Aorta
# 2    A_Brachiocephls           Brachiocephls_A  Brachiocephalic Artery
# 3          A_Carotid                 Carotid_A   Common Carotid Artery
# 4        A_Carotid_L               L_Carotid_A          Carotid Artery
#
#     FMAID Unnamed: 9
# 0  3734.0        NaN
# 1  3736.0        NaN
# 2  3932.0        NaN
# 3  3939.0        NaN
# 4  4058.0        NaN

# %%
print(harmonizer.TG_263_prime_name_col)
# Out:
# TG263-Primary Name

# %%
harmonizer.get_all_TG263names()

# %%
roi_dict_size = len(harmonizer.roi_dict)
TG263_dict_size = len(harmonizer.TG_263_names_to_match)
print('roi_dict_size: ', roi_dict_size, '||', 'TG263_dict_size: ', TG263_dict_size)
# Out:
# roi_dict_size:  3555 || TG263_dict_size:  717

# %%
for key,val in harmonizer.TG_263_names_to_match.items():
    print(key)
    print(val)
harmonizer.update_harmonized_df()
harmonizer.harmonize_df_get_scores()
# Out:
# A_Aorta
# ['A_Aorta', 'Aorta_A']
# A_Aorta_Asc
# ['A_Aorta_Asc', 'Asc_Aorta_A']
# A_Brachiocephls
# ['Brachiocephls_A', 'A_Brachiocephls']
# A_Carotid
# ['A_Carotid', 'Carotid_A']
# A_Carotid_L
# ['L_Carotid_A', 'A_Carotid_L']
# A_Carotid_R
# ['A_Carotid_R', 'R_Carotid_A']
# A_Celiac
# ['A_Celiac', 'Celiac_A']
# A_Coronary
# ['Coronary_A', 'A_Coronary']
# A_Coronary_L
# ['L_Coronary_A', 'A_Coronary_L']
# A_Coronary_R
# ['A_Coronary_R', 'R_Coronary_A']
# A_Femoral_Cflx_L
# ['A_Femoral_Cflx_L', 'L_Cflx_Femoral_A']
# A_Femoral_Cflx_R
# ['R_Cflx_Femoral_A', 'A_Femoral_Cflx_R']
# A_Femoral_L
# ['A_Femoral_L', 'L_Femoral_A']
# A_Femoral_R
# ['A_Femoral_R', 'R_Femoral_A']
# A_Humeral_Cflx_L
# ['A_Humeral_Cflx_L', 'L_Cflx_Humeral_A']
# A_Humeral_Cflx_R
# ['R_Cflx_Humeral_A', 'A_Humeral_Cflx_R']
# A_Humeral_L
# ['A_Humeral_L', 'L_Humeral_A']
# A_Humeral_R
# ['R_Humeral_A', 'A_Humeral_R']
# A_Hypophyseal_I
# ['I_Hypophyseal_A', 'A_Hypophyseal_I']
# A_Hypophyseal_S
# ['S_Hypophyseal_A', 'A_Hypophyseal_S']
# A_Iliac_Cflx_L
# ['A_Iliac_Cflx_L', 'L_Cflx_Iliac_A']
# A_Iliac_Cflx_R
# ['R_Cflx_Iliac_A', 'A_Iliac_Cflx_R']
# A_Iliac_Ext_L
# ['L_Ext_Iliac_A', 'A_Iliac_Ext_L']
# A_Iliac_Ext_R
# ['A_Iliac_Ext_R', 'R_Ext_Iliac_A']
# A_Iliac_Int_L
# ['A_Iliac_Int_L', 'L_Int_Iliac_A']
# A_Iliac_Int_R
# ['R_Int_Iliac_A', 'A_Iliac_Int_R']
# A_Iliac_L
# ['A_Iliac_L', 'L_Iliac_A']
# A_Iliac_R
# ['R_Iliac_A', 'A_Iliac_R']
# A_LAD
# ['LAD_A', 'A_LAD']
# A_Mesenteric_I
# ['I_Mesenteric_A', 'A_Mesenteric_I']
# A_Mesenteric_S
# ['S_Mesenteric_A', 'A_Mesenteric_S']
# A_Pulmonary
# ['A_Pulmonary', 'Pulmonary_A']
# A_Subclavian
# ['A_Subclavian', 'Subclavian_A']
# A_Subclavian_L
# ['L_Subclavian_A', 'A_Subclavian_L']
# A_Subclavian_R
# ['R_Subclavian_A', 'A_Subclavian_R']
# A_Vertebral
# ['Vertebral_A', 'A_Vertebral']
# A_Vertebral_L
# ['L_Vertebral_A', 'A_Vertebral_L']
# A_Vertebral_R
# ['A_Vertebral_R', 'R_Vertebral_A']
# Acetabulum_L
# ['L_Acetabulum', 'Acetabulum_L']
# Acetabulum_R
# ['R_Acetabulum', 'Acetabulum_R']
# Acetabulums
# ['Acetabulums']
# AirWay_Dist
# ['Dist_AirWay', 'AirWay_Dist']
# AirWay_Prox
# ['AirWay_Prox', 'Prox_AirWay']
# Anus
# ['Anus']
# Appendix
# ['Appendix']
# Arytenoid
# ['Arytenoid']
# Arytenoid_L
# ['L_Arytenoid', 'Arytenoid_L']
# Arytenoid_R
# ['Arytenoid_R', 'R_Arytenoid']
# Atrium
# ['Atrium']
# Atrium_L
# ['L_Atrium', 'Atrium_L']
# Atrium_R
# ['Atrium_R', 'R_Atrium']
# Bag_Bowel
# ['Bowel_Bag', 'Bag_Bowel']
# Bag_Ostomy
# ['Bag_Ostomy', 'Ostomy_Bag']
# BileDuct_Common
# ['Common_BileDuct', 'BileDuct_Common']
# Bladder
# ['Bladder']
# Bladder_Wall
# ['Bladder_Wall']
# Bladder-CTV
# ['Bladder-CTV']
# Body
# ['Body']
# Body-PTV
# ['Body-PTV']
# Bolus
# ['Bolus']
# Bolus_xxmm
# ['Bolus_xxmm', 'xxmm_Bolus']
# Bone
# ['Bone']
# Bone_Ethmoid
# ['Bone_Ethmoid', 'Ethmoid_Bone']
# Bone_Frontal
# ['Frontal_Bone', 'Bone_Frontal']
# Bone_Hyoid
# ['Hyoid_Bone', 'Bone_Hyoid']
# Bone_Ilium
# ['Ilium_Bone', 'Bone_Ilium']
# Bone_Ilium_L
# ['Bone_Ilium_L', 'L_Ilium_Bone']
# Bone_Ilium_R
# ['Bone_Ilium_R', 'R_Ilium_Bone']
# Bone_Incus
# ['Incus_Bone', 'Bone_Incus']
# Bone_Incus_L
# ['L_Incus_Bone', 'Bone_Incus_L']
# Bone_Incus_R
# ['R_Incus_Bone', 'Bone_Incus_R']
# Bone_Ischium_L
# ['L_Ischium_Bone', 'Bone_Ischium_L']
# Bone_Ischium_R
# ['Bone_Ischium_R', 'R_Ischium_Bone']
# Bone_Lacrimal
# ['Bone_Lacrimal', 'Lacrimal_Bone']
# Bone_Lacrimal_L
# ['Bone_Lacrimal_L', 'L_Lacrimal_Bone']
# Bone_Lacrimal_R
# ['Bone_Lacrimal_R', 'R_Lacrimal_Bone']
# Bone_Mandible
# ['Bone_Mandible', 'Mandible_Bone']
# Bone_Mastoid
# ['Bone_Mastoid', 'Mastoid_Bone']
# Bone_Mastoid_L
# ['L_Mastoid_Bone', 'Bone_Mastoid_L']
# Bone_Mastoid_R
# ['R_Mastoid_Bone', 'Bone_Mastoid_R']
# Bone_Nasal
# ['Nasal_Bone', 'Bone_Nasal']
# Bone_Nasal_L
# ['L_Nasal_Bone', 'Bone_Nasal_L']
# Bone_Nasal_R
# ['R_Nasal_Bone', 'Bone_Nasal_R']
# Bone_Occipital
# ['Occipital_Bone', 'Bone_Occipital']
# Bone_Palatine
# ['Bone_Palatine', 'Palatine_Bone']
# Bone_Palatine_L
# ['L_Palatine_Bone', 'Bone_Palatine_L']
# Bone_Palatine_R
# ['R_Palatine_Bone', 'Bone_Palatine_R']
# Bone_Parietal
# ['Parietal_Bone', 'Bone_Parietal']
# Bone_Parietal_L
# ['L_Parietal_Bone', 'Bone_Parietal_L']
# Bone_Parietal_R
# ['R_Parietal_Bone', 'Bone_Parietal_R']
# Bone_Pelvic
# ['Pelvic_Bone', 'Bone_Pelvic']
# Bone_Pelvic_L
# ['Bone_Pelvic_L', 'L_Pelvic_Bone']
# Bone_Pelvic_R
# ['Bone_Pelvic_R', 'R_Pelvic_Bone']
# Bone_Sphenoid
# ['Sphenoid_Bone', 'Bone_Sphenoid']
# Bone_Temporal
# ['Temporal_Bone', 'Bone_Temporal']
# Bone_Temporal_L
# ['Bone_Temporal_L', 'L_Temporal_Bone']
# Bone_Temporal_R
# ['R_Temporal_Bone', 'Bone_Temporal_R']
# Bone_Zygomatic_L
# ['Bone_Zygomatic_L', 'L_Zygomatic_Bone']
# Bone_Zygomatic_R
# ['Bone_Zygomatic_R', 'R_Zygomatic_Bone']
# Bone_Zygomatics
# ['Bone_Zygomatics', 'Zygomatics_Bone']
# BoneMarrow
# ['BoneMarrow']
# BoneMarrow_Act
# ['Act_BoneMarrow', 'BoneMarrow_Act']
# Boost
# ['Boost']
# Bowel
# ['Bowel']
# Bowel_Large
# ['Large_Bowel', 'Bowel_Large']
# Bowel_Small
# ['Small_Bowel', 'Bowel_Small']
# BrachialPlex_L
# ['BrachialPlex_L', 'L_BrachialPlex']
# BrachialPlex_R
# ['R_BrachialPlex', 'BrachialPlex_R']
# BrachialPlexs
# ['BrachialPlexs']
# Brain
# ['Brain']
# Brain-CTV
# ['Brain-CTV']
# Brain-GTV
# ['Brain-GTV']
# Brain-PTV
# ['Brain-PTV']
# Brainstem
# ['Brainstem']
# Brainstem_Core
# ['Brainstem_Core', 'Core_Brainstem']
# Brainstem_PRV
# ['Brainstem_PRV', 'PRV_Brainstem']
# Brainstem_PRVxx
# ['Brainstem_PRVxx', 'PRVxx_Brainstem']
# Brainstem_Surf
# ['Surf_Brainstem', 'Brainstem_Surf']
# Breast_L
# ['L_Breast', 'Breast_L']
# Breast_R
# ['R_Breast', 'Breast_R']
# Breasts
# ['Breasts']
# Bronchus
# ['Bronchus']
# Bronchus_L
# ['Bronchus_L', 'L_Bronchus']
# Bronchus_Main
# ['Bronchus_Main', 'Main_Bronchus']
# Bronchus_Main_L
# ['L_Main_Bronchus', 'Bronchus_Main_L']
# Bronchus_Main_R
# ['Bronchus_Main_R', 'R_Main_Bronchus']
# Bronchus_PRVxx
# ['PRVxx_Bronchus', 'Bronchus_PRVxx']
# Bronchus_R
# ['Bronchus_R', 'R_Bronchus']
# Canal_Anal
# ['Canal_Anal', 'Anal_Canal']
# Carina
# ['Carina']
# Cartlg_Thyroid
# ['Cartlg_Thyroid', 'Thyroid_Cartlg']
# CaudaEquina
# ['CaudaEquina']
# Cavernosum
# ['Cavernosum']
# Cavity_Nasal
# ['Cavity_Nasal', 'Nasal_Cavity']
# Cavity_Oral
# ['Oral_Cavity', 'Cavity_Oral']
# Cecum
# ['Cecum']
# Cerebellum
# ['Cerebellum']
# Cerebrum
# ['Cerebrum']
# Cerebrum_L
# ['L_Cerebrum', 'Cerebrum_L']
# Cerebrum_R
# ['Cerebrum_R', 'R_Cerebrum']
# Cervix
# ['Cervix']
# Chestwall
# ['Chestwall']
# Chestwall_L
# ['Chestwall_L', 'L_Chestwall']
# Chestwall_R
# ['R_Chestwall', 'Chestwall_R']
# Cist_Pontine
# ['Pontine_Cist', 'Cist_Pontine']
# Cist_Suprasellar
# ['Suprasellar_Cist', 'Cist_Suprasellar']
# Clavicle_L
# ['L_Clavicle', 'Clavicle_L']
# Clavicle_R
# ['R_Clavicle', 'Clavicle_R']
# CN_III
# ['CN_III', 'III_CN']
# CN_III_L
# ['CN_III_L', 'L_III_CN']
# CN_III_R
# ['CN_III_R', 'R_III_CN']
# CN_IX
# ['IX_CN', 'CN_IX']
# CN_IX_L
# ['L_IX_CN', 'CN_IX_L']
# CN_IX_R
# ['R_IX_CN', 'CN_IX_R']
# CN_V
# ['V_CN', 'CN_V']
# CN_V_L
# ['CN_V_L', 'L_V_CN']
# CN_V_R
# ['CN_V_R', 'R_V_CN']
# CN_VI
# ['VI_CN', 'CN_VI']
# CN_VI_L
# ['L_VI_CN', 'CN_VI_L']
# CN_VI_R
# ['CN_VI_R', 'R_VI_CN']
# CN_VII
# ['VII_CN', 'CN_VII']
# CN_VII_L
# ['CN_VII_L', 'L_VII_CN']
# CN_VII_R
# ['R_VII_CN', 'CN_VII_R']
# CN_VIII
# ['VIII_CN', 'CN_VIII']
# CN_VIII_L
# ['CN_VIII_L', 'L_VIII_CN']
# CN_VIII_R
# ['R_VIII_CN', 'CN_VIII_R']
# CN_XI
# ['XI_CN', 'CN_XI']
# CN_XI_L
# ['CN_XI_L', 'L_XI_CN']
# CN_XI_R
# ['CN_XI_R', 'R_XI_CN']
# CN_XII
# ['XII_CN', 'CN_XII']
# CN_XII_L
# ['CN_XII_L', 'L_XII_CN']
# CN_XII_R
# ['R_XII_CN', 'CN_XII_R']
# Cochlea
# ['Cochlea']
# Cochlea_L
# ['Cochlea_L', 'L_Cochlea']
# Cochlea_R
# ['R_Cochlea', 'Cochlea_R']
# Colon
# ['Colon']
# Colon_Ascending
# ['Ascending_Colon', 'Colon_Ascending']
# Colon_Decending
# ['Decending_Colon', 'Colon_Decending']
# Colon_PTVxx
# ['Colon_PTVxx', 'PTVxx_Colon']
# Colon_Sigmoid
# ['Sigmoid_Colon', 'Colon_Sigmoid']
# Colon_Transverse
# ['Colon_Transverse', 'Transverse_Colon']
# Cornea
# ['Cornea']
# Cornea_L
# ['Cornea_L', 'L_Cornea']
# Cornea_R
# ['Cornea_R', 'R_Cornea']
# CribriformPlate
# ['CribriformPlate']
# Cricoid
# ['Cricoid']
# Cricopharyngeus
# ['Cricopharyngeus']
# CTV
# ['CTV']
# Dens
# ['Dens']
# Diaphragm
# ['Diaphragm']
# Duodenum
# ['Duodenum']
# Ear_External_L
# ['L_External_Ear', 'Ear_External_L']
# Ear_External_R
# ['Ear_External_R', 'R_External_Ear']
# Ear_Externals
# ['Ear_Externals', 'Externals_Ear']
# Ear_Internal_L
# ['L_Internal_Ear', 'Ear_Internal_L']
# Ear_Internal_R
# ['R_Internal_Ear', 'Ear_Internal_R']
# Ear_Internals
# ['Internals_Ear', 'Ear_Internals']
# Ear_Middle
# ['Middle_Ear', 'Ear_Middle']
# Ear_Middle_L
# ['L_Middle_Ear', 'Ear_Middle_L']
# Ear_Middle_R
# ['R_Middle_Ear', 'Ear_Middle_R']
# Edema
# ['Edema']
# Elbow
# ['Elbow']
# Elbow_L
# ['L_Elbow', 'Elbow_L']
# Elbow_R
# ['R_Elbow', 'Elbow_R']
# E-PTV_Ev05_xxxx
# ['E-PTV_Ev05_xxxx']
# E-PTV_xxxx
# ['E-PTV_xxxx']
# Esophagus
# ['Esophagus']
# Esophagus_I
# ['I_Esophagus', 'Esophagus_I']
# Esophagus_M
# ['Esophagus_M', 'M_Esophagus']
# Esophagus_NAdj
# ['NAdj_Esophagus', 'Esophagus_NAdj']
# Esophagus_S
# ['Esophagus_S', 'S_Esophagus']
# Eval
# ['Eval']
# External
# ['External']
# Eye_L
# ['L_Eye', 'Eye_L']
# Eye_R
# ['Eye_R', 'R_Eye']
# Eyes
# ['Eyes']
# Femur_Base_L
# ['L_Base_Femur', 'Femur_Base_L']
# Femur_Base_R
# ['R_Base_Femur', 'Femur_Base_R']
# Femur_Head_L
# ['L_Head_Femur', 'Femur_Head_L']
# Femur_Head_R
# ['R_Head_Femur', 'Femur_Head_R']
# Femur_Joint_L
# ['Femur_Joint_L', 'L_Joint_Femur']
# Femur_Joint_R
# ['Femur_Joint_R', 'R_Joint_Femur']
# Femur_L
# ['L_Femur', 'Femur_L']
# Femur_Neck_L
# ['Femur_Neck_L', 'L_Neck_Femur']
# Femur_Neck_R
# ['Femur_Neck_R', 'R_Neck_Femur']
# Femur_R
# ['R_Femur', 'Femur_R']
# Femur_Shaft_L
# ['L_Shaft_Femur', 'Femur_Shaft_L']
# Femur_Shaft_R
# ['R_Shaft_Femur', 'Femur_Shaft_R']
# Femurs
# ['Femurs']
# Fibula
# ['Fibula']
# Fibula_L
# ['Fibula_L', 'L_Fibula']
# Fibula_R
# ['Fibula_R', 'R_Fibula']
# Foley
# ['Foley']
# Fossa_Jugular
# ['Fossa_Jugular', 'Jugular_Fossa']
# Fossa_Posterior
# ['Fossa_Posterior', 'Posterior_Fossa']
# Gallbladder
# ['Gallbladder']
# Genitals
# ['Genitals']
# Glnd_Adrenal_L
# ['L_Adrenal_Glnd', 'Glnd_Adrenal_L']
# Glnd_Adrenal_R
# ['R_Adrenal_Glnd', 'Glnd_Adrenal_R']
# Glnd_Lacrimal
# ['Lacrimal_Glnd', 'Glnd_Lacrimal']
# Glnd_Lacrimal_L
# ['L_Lacrimal_Glnd', 'Glnd_Lacrimal_L']
# Glnd_Lacrimal_R
# ['Glnd_Lacrimal_R', 'R_Lacrimal_Glnd']
# Glnd_Parathyroid
# ['Parathyroid_Glnd', 'Glnd_Parathyroid']
# Glnd_Subling_L
# ['L_Subling_Glnd', 'Glnd_Subling_L']
# Glnd_Subling_R
# ['Glnd_Subling_R', 'R_Subling_Glnd']
# Glnd_Sublings
# ['Glnd_Sublings', 'Sublings_Glnd']
# Glnd_Submand_L
# ['Glnd_Submand_L', 'L_Submand_Glnd']
# Glnd_Submand_R
# ['Glnd_Submand_R', 'R_Submand_Glnd']
# Glnd_Submands
# ['Submands_Glnd', 'Glnd_Submands']
# Glnd_Thymus
# ['Thymus_Glnd', 'Glnd_Thymus']
# Glnd_Thyroid
# ['Glnd_Thyroid', 'Thyroid_Glnd']
# Glottis
# ['Glottis']
# GreatVes
# ['GreatVes']
# GreatVes_NAdj
# ['NAdj_GreatVes', 'GreatVes_NAdj']
# GrowthPlate_L
# ['GrowthPlate_L', 'L_GrowthPlate']
# GrowthPlate_R
# ['GrowthPlate_R', 'R_GrowthPlate']
# GTV
# ['GTV']
# Hardpalate
# ['Hardpalate']
# Heart
# ['Heart']
# Hemisphere_L
# ['L_Hemisphere', 'Hemisphere_L']
# Hemisphere_R
# ['Hemisphere_R', 'R_Hemisphere']
# Hemispheres
# ['Hemispheres']
# Hippocampi
# ['Hippocampi']
# Hippocampus_L
# ['L_Hippocampus', 'Hippocampus_L']
# Hippocampus_R
# ['R_Hippocampus', 'Hippocampus_R']
# Humerus_L
# ['L_Humerus', 'Humerus_L']
# Humerus_R
# ['R_Humerus', 'Humerus_R']
# Hypothalmus
# ['Hypothalmus']
# Hypothalmus_PRV
# ['Hypothalmus_PRV', 'PRV_Hypothalmus']
# Hypothalmus_PRVx
# ['PRVx_Hypothalmus', 'Hypothalmus_PRVx']
# IDL
# ['IDL']
# Ileum
# ['Ileum']
# ITV
# ['ITV']
# Jejunum
# ['Jejunum']
# Jejunum_Ileum
# ['Jejunum_Ileum']
# Joint_Elbow
# ['Joint_Elbow', 'Elbow_Joint']
# Joint_Elbow_L
# ['L_Elbow_Joint', 'Joint_Elbow_L']
# Joint_Elbow_R
# ['Joint_Elbow_R', 'R_Elbow_Joint']
# Joint_Glenohum
# ['Glenohum_Joint', 'Joint_Glenohum']
# Joint_Glenohum_L
# ['L_Glenohum_Joint', 'Joint_Glenohum_L']
# Joint_Glenohum_R
# ['Joint_Glenohum_R', 'R_Glenohum_Joint']
# Joint_Surface
# ['Joint_Surface', 'Surface_Joint']
# Joint_TM
# ['Joint_TM', 'TM_Joint']
# Joint_TM_L
# ['L_TM_Joint', 'Joint_TM_L']
# Joint_TM_R
# ['R_TM_Joint', 'Joint_TM_R']
# Kidney_Cortex
# ['Kidney_Cortex', 'Cortex_Kidney']
# Kidney_Cortex_L
# ['Kidney_Cortex_L', 'L_Cortex_Kidney']
# Kidney_Cortex_R
# ['Kidney_Cortex_R', 'R_Cortex_Kidney']
# Kidney_Hilum_L
# ['L_Hilum_Kidney', 'Kidney_Hilum_L']
# Kidney_Hilum_R
# ['Kidney_Hilum_R', 'R_Hilum_Kidney']
# Kidney_Hilums
# ['Kidney_Hilums', 'Hilums_Kidney']
# Kidney_L
# ['Kidney_L', 'L_Kidney']
# Kidney_L-GTV
# ['L_Kidney-GTV', 'Kidney_L-GTV']
# Kidney_Pelvis_L
# ['Kidney_Pelvis_L', 'L_Pelvis_Kidney']
# Kidney_Pelvis_R
# ['R_Pelvis_Kidney', 'Kidney_Pelvis_R']
# Kidney_R
# ['Kidney_R', 'R_Kidney']
# Kidney_R-GTV
# ['R_Kidney-GTV', 'Kidney_R-GTV']
# Kidney-GTV
# ['Kidney-GTV']
# Kidneys
# ['Kidneys']
# Knee
# ['Knee']
# Knee_L
# ['Knee_L', 'L_Knee']
# Knee_R
# ['R_Knee', 'Knee_R']
# Laryngl_Pharynx
# ['Laryngl_Pharynx', 'Pharynx_Laryngl']
# Larynx
# ['Larynx']
# Larynx_SG
# ['Larynx_SG', 'SG_Larynx']
# Leads
# ['Leads']
# Lens
# ['Lens']
# Lens_L
# ['L_Lens', 'Lens_L']
# Lens_R
# ['Lens_R', 'R_Lens']
# Lig_Hepatogastrc
# ['Lig_Hepatogastrc', 'Hepatogastrc_Lig']
# Lips
# ['Lips']
# Liver
# ['Liver']
# Liver-CTV
# ['Liver-CTV']
# Liver-GTV
# ['Liver-GTV']
# LN
# ['LN']
# LN_Ax_Apical
# ['LN_Ax_Apical', 'Apical_Ax_LN']
# LN_Ax_Apical_L
# ['LN_Ax_Apical_L', 'L_Apical_Ax_LN']
# LN_Ax_Apical_R
# ['R_Apical_Ax_LN', 'LN_Ax_Apical_R']
# LN_Ax_Central_L
# ['L_Central_Ax_LN', 'LN_Ax_Central_L']
# LN_Ax_Central_R
# ['LN_Ax_Central_R', 'R_Central_Ax_LN']
# LN_Ax_Centrals
# ['Centrals_Ax_LN', 'LN_Ax_Centrals']
# LN_Ax_L
# ['LN_Ax_L', 'L_Ax_LN']
# LN_Ax_L1_L
# ['LN_Ax_L1_L', 'L_L1_Ax_LN']
# LN_Ax_L1_R
# ['R_L1_Ax_LN', 'LN_Ax_L1_R']
# LN_Ax_L2_L
# ['LN_Ax_L2_L', 'L_L2_Ax_LN']
# LN_Ax_L2_R
# ['R_L2_Ax_LN', 'LN_Ax_L2_R']
# LN_Ax_L3_L
# ['LN_Ax_L3_L', 'L_L3_Ax_LN']
# LN_Ax_L3_R
# ['LN_Ax_L3_R', 'R_L3_Ax_LN']
# LN_Ax_Lateral_L
# ['LN_Ax_Lateral_L', 'L_Lateral_Ax_LN']
# LN_Ax_Lateral_R
# ['R_Lateral_Ax_LN', 'LN_Ax_Lateral_R']
# LN_Ax_Laterals
# ['Laterals_Ax_LN', 'LN_Ax_Laterals']
# LN_Ax_Pectoral_L
# ['L_Pectoral_Ax_LN', 'LN_Ax_Pectoral_L']
# LN_Ax_Pectoral_R
# ['R_Pectoral_Ax_LN', 'LN_Ax_Pectoral_R']
# LN_Ax_Pectorals
# ['Pectorals_Ax_LN', 'LN_Ax_Pectorals']
# LN_Ax_R
# ['R_Ax_LN', 'LN_Ax_R']
# LN_Ax_Subscap_L
# ['LN_Ax_Subscap_L', 'L_Subscap_Ax_LN']
# LN_Ax_Subscap_R
# ['LN_Ax_Subscap_R', 'R_Subscap_Ax_LN']
# LN_Ax_Subscaps
# ['LN_Ax_Subscaps', 'Subscaps_Ax_LN']
# LN_Brachioceph_L
# ['L_Brachioceph_LN', 'LN_Brachioceph_L']
# LN_Brachioceph_R
# ['R_Brachioceph_LN', 'LN_Brachioceph_R']
# LN_Brachiocephs
# ['Brachiocephs_LN', 'LN_Brachiocephs']
# LN_Bronchpulm_L
# ['LN_Bronchpulm_L', 'L_Bronchpulm_LN']
# LN_Bronchpulm_R
# ['R_Bronchpulm_LN', 'LN_Bronchpulm_R']
# LN_Bronchpulms
# ['LN_Bronchpulms', 'Bronchpulms_LN']
# LN_Diaphragmatic
# ['Diaphragmatic_LN', 'LN_Diaphragmatic']
# LN_Iliac_Ext_L
# ['L_Ext_Iliac_LN', 'LN_Iliac_Ext_L']
# LN_Iliac_Ext_R
# ['R_Ext_Iliac_LN', 'LN_Iliac_Ext_R']
# LN_Iliac_Int_L
# ['L_Int_Iliac_LN', 'LN_Iliac_Int_L']
# LN_Iliac_L
# ['LN_Iliac_L', 'L_Iliac_LN']
# LN_Iliac_R
# ['LN_Iliac_R', 'R_Iliac_LN']
# LN_IMN_L
# ['L_IMN_LN', 'LN_IMN_L']
# LN_IMN_R
# ['LN_IMN_R', 'R_IMN_LN']
# LN_IMNs
# ['LN_IMNs', 'IMNs_LN']
# LN_Inguinofem
# ['Inguinofem_LN', 'LN_Inguinofem']
# LN_Inguinofem_L
# ['L_Inguinofem_LN', 'LN_Inguinofem_L']
# LN_Inguinofem_R
# ['R_Inguinofem_LN', 'LN_Inguinofem_R']
# LN_Intercostals
# ['LN_Intercostals', 'Intercostals_LN']
# LN_L
# ['L_LN', 'LN_L']
# LN_Ligamentarter
# ['LN_Ligamentarter', 'Ligamentarter_LN']
# LN_lliac_Int_R
# ['R_Int_Iliac_LN', 'LN_lliac_Int_R']
# LN_Mediastinals
# ['Mediastinals_LN', 'LN_Mediastinals']
# LN_Neck_IA_L
# ['L_IA_Neck_LN', 'LN_Neck_IA_L']
# LN_Neck_IA_R
# ['R_IA_Neck_LN', 'LN_Neck_IA_R']
# LN_Neck_IB_L
# ['L_IB_Neck_LN', 'LN_Neck_IB_L']
# LN_Neck_IB_R
# ['R_IB_Neck_LN', 'LN_Neck_IB_R']
# LN_Neck_II_L
# ['LN_Neck_II_L', 'L_II_Neck_LN']
# LN_Neck_II_R
# ['R_II_Neck_LN', 'LN_Neck_II_R']
# LN_Neck_IIA_L
# ['LN_Neck_IIA_L', 'L_IIA_Neck_LN']
# LN_Neck_IIA_R
# ['R_IIA_Neck_LN', 'LN_Neck_IIA_R']
# LN_Neck_IIB_L
# ['L_IIB_Neck_LN', 'LN_Neck_IIB_L']
# LN_Neck_IIB_R
# ['R_IIB_Neck_LN', 'LN_Neck_IIB_R']
# LN_Neck_III_L
# ['L_III_Neck_LN', 'LN_Neck_III_L']
# LN_Neck_III_R
# ['LN_Neck_III_R', 'R_III_Neck_LN']
# LN_Neck_IV_L
# ['L_IV_Neck_LN', 'LN_Neck_IV_L']
# LN_Neck_IV_R
# ['LN_Neck_IV_R', 'R_IV_Neck_LN']
# LN_Neck_V_L
# ['LN_Neck_V_L', 'L_V_Neck_LN']
# LN_Neck_V_R
# ['LN_Neck_V_R', 'R_V_Neck_LN']
# LN_Neck_VA_L
# ['LN_Neck_VA_L', 'L_VA_Neck_LN']
# LN_Neck_VA_R
# ['LN_Neck_VA_R', 'R_VA_Neck_LN']
# LN_Neck_VB_L
# ['L_VB_Neck_LN', 'LN_Neck_VB_L']
# LN_Neck_VB_R
# ['LN_Neck_VB_R', 'R_VB_Neck_LN']
# LN_Neck_VC_L
# ['L_VC_Neck_LN', 'LN_Neck_VC_L']
# LN_Neck_VC_R
# ['R_VC_Neck_LN', 'LN_Neck_VC_R']
# LN_Neck_VI_L
# ['LN_Neck_VI_L', 'L_VI_Neck_LN']
# LN_Neck_VI_R
# ['LN_Neck_VI_R', 'R_VI_Neck_LN']
# LN_Neck_VII_L
# ['L_VII_Neck_LN', 'LN_Neck_VII_L']
# LN_Neck_VII_R
# ['LN_Neck_VII_R', 'R_VII_Neck_LN']
# LN_Obturator_L
# ['LN_Obturator_L', 'L_Obturator_LN']
# LN_Obturator_R
# ['R_Obturator_LN', 'LN_Obturator_R']
# LN_Paraaortic
# ['LN_Paraaortic', 'Paraaortic_LN']
# LN_Paramammary_L
# ['L_Paramammary_LN', 'LN_Paramammary_L']
# LN_Paramammary_R
# ['LN_Paramammary_R', 'R_Paramammary_LN']
# LN_Paramammarys
# ['LN_Paramammarys', 'Paramammarys_LN']
# LN_Parasternal_L
# ['LN_Parasternal_L', 'L_Parasternal_LN']
# LN_Parasternal_R
# ['LN_Parasternal_R', 'R_Parasternal_LN']
# LN_Parasternals
# ['Parasternals_LN', 'LN_Parasternals']
# LN_Pelvic_L
# ['L_Pelvic_LN', 'LN_Pelvic_L']
# LN_Pelvic_R
# ['R_Pelvic_LN', 'LN_Pelvic_R']
# LN_Pelvics
# ['LN_Pelvics', 'Pelvics_LN']
# LN_Portahepatis
# ['LN_Portahepatis', 'Portahepatis_LN']
# LN_Presacral_L
# ['LN_Presacral_L', 'L_Presacral_LN']
# LN_Presacral_R
# ['R_Presacral_LN', 'LN_Presacral_R']
# LN_Pulmonary_L
# ['L_Pulmonary_LN', 'LN_Pulmonary_L']
# LN_Pulmonary_R
# ['R_Pulmonary_LN', 'LN_Pulmonary_R']
# LN_Pulmonarys
# ['LN_Pulmonarys', 'Pulmonarys_LN']
# LN_R
# ['R_LN', 'LN_R']
# LN_Sclav_L
# ['L_Sclav_LN', 'LN_Sclav_L']
# LN_Sclav_R
# ['LN_Sclav_R', 'R_Sclav_LN']
# LN_Supmammary_L
# ['LN_Supmammary_L', 'L_Supmammary_LN']
# LN_Supmammary_R
# ['LN_Supmammary_R', 'R_Supmammary_LN']
# LN_Supmammarys
# ['LN_Supmammarys', 'Supmammarys_LN']
# LN_Trachbrnchs
# ['Trachbronchs_LN', 'LN_Trachbrnchs']
# LN_Trachbrnchs_L
# ['LN_Trachbrnchs_L', 'L_Trachbronchs_LN']
# LN_Trachbrnchs_R
# ['LN_Trachbrnchs_R', 'R_Trachbronchs_LN']
# Lobe_Frontal
# ['Lobe_Frontal', 'Frontal_Lobe']
# Lobe_Frontal_L
# ['Lobe_Frontal_L', 'L_Frontal_Lobe']
# Lobe_Frontal_R
# ['R_Frontal_Lobe', 'Lobe_Frontal_R']
# Lobe_Occipital
# ['Occipital_Lobe', 'Lobe_Occipital']
# Lobe_Occipital_L
# ['L_Occipital_Lobe', 'Lobe_Occipital_L']
# Lobe_Occipital_R
# ['Lobe_Occipital_R', 'R_Occipital_Lobe']
# Lobe_Parietal
# ['Lobe_Parietal', 'Parietal_Lobe']
# Lobe_Parietal_L
# ['L_Parietal_Lobe', 'Lobe_Parietal_L']
# Lobe_Parietal_R
# ['R_Parietal_Lobe', 'Lobe_Parietal_R']
# Lobe_Temporal
# ['Temporal_Lobe', 'Lobe_Temporal']
# Lobe_Temporal_L
# ['Lobe_Temporal_L', 'L_Temporal_Lobe']
# Lobe_Temporal_R
# ['R_Temporal_Lobe', 'Lobe_Temporal_R']
# Lung_L
# ['L_Lung', 'Lung_L']
# Lung_LLL
# ['Lung_LLL', 'LLL_Lung']
# Lung_LUL
# ['LUL_Lung', 'Lung_LUL']
# Lung_R
# ['Lung_R', 'R_Lung']
# Lung_RLL
# ['Lung_RLL', 'RLL_Lung']
# Lung_RML
# ['Lung_RML', 'RML_Lung']
# Lung_RUL
# ['Lung_RUL', 'RUL_Lung']
# Lungs
# ['Lungs']
# Lungs-CTV
# ['Lungs-CTV']
# Lungs-GTV
# ['Lungs-GTV']
# Lungs-ITV
# ['Lungs-ITV']
# Lungs-PTV
# ['Lungs-PTV']
# Malleus
# ['Malleus']
# Malleus_L
# ['L_Malleus', 'Malleus_L']
# Malleus_R
# ['R_Malleus', 'Malleus_R']
# Markers
# ['Markers']
# Maxilla
# ['Maxilla']
# Maxilla_L
# ['Maxilla_L', 'L_Maxilla']
# Maxilla_R
# ['Maxilla_R', 'R_Maxilla']
# Mediastinum
# ['Mediastinum']
# Musc
# ['Musc']
# Musc_Constrict
# ['Musc_Constrict', 'Constrict_Musc']
# Musc_Constrict_I
# ['Musc_Constrict_I', 'I_Constrict_Musc']
# Musc_Constrict_M
# ['M_Constrict_Musc', 'Musc_Constrict_M']
# Musc_Constrict_S
# ['S_Constrict_Musc', 'Musc_Constrict_S']
# Musc_Digastric_L
# ['Musc_Digastric_L', 'L_Digastric_Musc']
# Musc_Digastric_R
# ['R_Digastric_Musc', 'Musc_Digastric_R']
# Musc_Masseter
# ['Masseter_Musc', 'Musc_Masseter']
# Musc_Masseter_L
# ['L_Masseter_Musc', 'Musc_Masseter_L']
# Musc_Masseter_R
# ['R_Masseter_Musc', 'Musc_Masseter_R']
# Musc_Platysma_L
# ['Musc_Platysma_L', 'L_Platysma_Musc']
# Musc_Platysma_R
# ['R_Platysma_Musc', 'Musc_Platysma_R']
# Musc_Pterygoid_L
# ['Musc_Pterygoid_L', 'L_Pterygoid_Musc']
# Musc_Pterygoid_R
# ['R_Pterygoid_Musc', 'Musc_Pterygoid_R']
# Musc_Sclmast_L
# ['Musc_Sclmast_L', 'L_Sclmast_Musc']
# Musc_Sclmast_R
# ['R_Sclmast_Musc', 'Musc_Sclmast_R']
# Musc_Temporal_L
# ['Musc_Temporal_L', 'L_Temporal_Musc']
# Musc_Temporal_R
# ['Musc_Temporal_R', 'R_Temporal_Musc']
# Nasalconcha_LI
# ['LI_Nasalconcha', 'Nasalconcha_LI']
# Nasalconcha_RI
# ['Nasalconcha_RI', 'RI_Nasalconcha']
# Nasopharynx
# ['Nasopharynx']
# Nose
# ['Nose']
# Nrv_Peripheral
# ['Peripheral_Nrv', 'Nrv_Peripheral']
# Nrv_Root
# ['Nrv_Root', 'Root_Nrv']
# OpticChiasm
# ['OpticChiasm']
# OpticChiasm_PRV
# ['OpticChiasm_PRV', 'PRV_OpticChiasm']
# OpticChiasm_PRVx
# ['OpticChiasm_PRVx', 'PRVx_OpticChiasm']
# OpticNrv
# ['OpticNrv']
# OpticNrv_L
# ['OpticNrv_L', 'L_OpticNrv']
# OpticNrv_PRV
# ['PRV_OpticNrv', 'OpticNrv_PRV']
# OpticNrv_PRV_L
# ['L_PRV_OpticNrv', 'OpticNrv_PRV_L']
# OpticNrv_PRV_R
# ['OpticNrv_PRV_R', 'R_PRV_OpticNrv']
# OpticNrv_PRVxx_L
# ['L_PRVxx_OpticNrv', 'OpticNrv_PRVxx_L']
# OpticNrv_PRVxx_R
# ['OpticNrv_PRVxx_R', 'R_PRVxx_OpticNrv']
# OpticNrv_R
# ['R_OpticNrv', 'OpticNrv_R']
# Orbit_L
# ['Orbit_L', 'L_Orbit']
# Orbit_R
# ['R_Orbit', 'Orbit_R']
# Oropharynx
# ['Oropharynx']
# Ovaries
# ['Ovaries']
# Ovary_L
# ['Ovary_L', 'L_Ovary']
# Ovary_R
# ['Ovary_R', 'R_Ovary']
# Pacemaker
# ['Pacemaker']
# Palate_Soft
# ['Soft_Palate', 'Palate_Soft']
# PancJejuno
# ['PancJejuno']
# Pancreas
# ['Pancreas']
# Pancreas_Head
# ['Pancreas_Head', 'Head_Pancreas']
# Pancreas_Tail
# ['Pancreas_Tail', 'Tail_Pancreas']
# Parametrium
# ['Parametrium']
# Parotid_L
# ['L_Parotid', 'Parotid_L']
# Parotid_R
# ['R_Parotid', 'Parotid_R']
# Parotids
# ['Parotids']
# PenileBulb
# ['PenileBulb']
# Penis
# ['Penis']
# Pericardium
# ['Pericardium']
# Perineum
# ['Perineum']
# Peritoneum
# ['Peritoneum']
# Pharynx
# ['Pharynx']
# Pineal
# ['Pineal']
# Pituitary
# ['Pituitary']
# Pituitary_PRVxx
# ['Pituitary_PRVxx', 'PRVxx_Pituitary']
# Pons
# ['Pons']
# Postop
# ['Postop']
# Preop
# ['Preop']
# Proc_Condyloid_L
# ['Proc_Condyloid_L', 'L_Condyloid_Proc']
# Proc_Condyloid_R
# ['R_Condyloid_Proc', 'Proc_Condyloid_R']
# Proc_Coronoid_L
# ['L_Coronoid_Proc', 'Proc_Coronoid_L']
# Proc_Coronoid_R
# ['R_Coronoid_Proc', 'Proc_Coronoid_R']
# Prostate
# ['Prostate']
# ProstateBed
# ['ProstateBed']
# Prosthesis
# ['Prosthesis']
# Pterygoid_Lat_L
# ['L_Lat_Pterygoid', 'Pterygoid_Lat_L']
# Pterygoid_Lat_R
# ['Pterygoid_Lat_R', 'R_Lat_Pterygoid']
# Pterygoid_Med_L
# ['L_Med_Pterygoid', 'Pterygoid_Med_L']
# Pterygoid_Med_R
# ['Pterygoid_Med_R', 'R_Med_Pterygoid']
# PTV
# ['PTV']
# PubicSymphys
# ['PubicSymphys']
# PubicSymphys_L
# ['PubicSymphys_L', 'L_PubicSymphys']
# PubicSymphys_R
# ['R_PubicSymphys', 'PubicSymphys_R']
# Radius_L
# ['L_Radius', 'Radius_L']
# Radius_R
# ['Radius_R', 'R_Radius']
# Rectal_Wall
# ['Rectal_Wall']
# Rectum
# ['Rectum']
# Retina_L
# ['L_Retina', 'Retina_L']
# Retina_PRVxx_L
# ['L_PRVxx_Retina', 'Retina_PRVxx_L']
# Retina_PRVxx_R
# ['R_PRVxx_Retina', 'Retina_PRVxx_R']
# Retina_R
# ['Retina_R', 'R_Retina']
# Retinas
# ['Retinas']
# Rib
# ['Rib']
# Rib01_L
# ['Rib01_L', 'L_Rib01']
# Rib01_R
# ['Rib01_R', 'R_Rib01']
# Rib02_L
# ['L_Rib02', 'Rib02_L']
# Rib02_R
# ['Rib02_R', 'R_Rib02']
# Rib03_L
# ['Rib03_L', 'L_Rib03']
# Rib03_R
# ['Rib03_R', 'R_Rib03']
# Rib04_L
# ['Rib04_L', 'L_Rib04']
# Rib04_R
# ['Rib04_R', 'R_Rib04']
# Rib05_L
# ['Rib05_L', 'L_Rib05']
# Rib05_R
# ['R_Rib05', 'Rib05_R']
# Rib06_L
# ['Rib06_L', 'L_Rib06']
# Rib06_R
# ['Rib06_R', 'R_Rib06']
# Rib07_L
# ['L_Rib07', 'Rib07_L']
# Rib07_R
# ['R_Rib07', 'Rib07_R']
# Rib08_L
# ['L_Rib08', 'Rib08_L']
# Rib08_R
# ['Rib08_R', 'R_Rib08']
# Rib09_L
# ['L_Rib09', 'Rib09_L']
# Rib09_R
# ['Rib09_R', 'R_Rib09']
# Rib10_L
# ['L_Rib10', 'Rib10_L']
# Rib10_R
# ['Rib10_R', 'R_Rib10']
# Rib11_L
# ['L_Rib11', 'Rib11_L']
# Rib11_R
# ['Rib11_R', 'R_Rib11']
# Rib12_L
# ['L_Rib12', 'Rib12_L']
# Rib12_R
# ['Rib12_R', 'R_Rib12']
# SacralPlex
# ['SacralPlex']
# Sacrum
# ['Sacrum']
# Scalp
# ['Scalp']
# Scapula_L
# ['Scapula_L', 'L_Scapula']
# Scapula_R
# ['Scapula_R', 'R_Scapula']
# Scar
# ['Scar']
# Scar_Boost
# ['Boost_Scar', 'Scar_Boost']
# Scrotum
# ['Scrotum']
# SeminalVes
# ['SeminalVes']
# SeminalVes_Dist
# ['Dist_SeminalVes', 'SeminalVes_Dist']
# SeminalVes_Prox
# ['SeminalVes_Prox', 'Prox_SeminalVes']
# Sinus_Ethmoid
# ['Ethmoid_Sinus', 'Sinus_Ethmoid']
# Sinus_Frontal
# ['Frontal_Sinus', 'Sinus_Frontal']
# Sinus_Frontal_L
# ['L_Frontal_Sinus', 'Sinus_Frontal_L']
# Sinus_Frontal_R
# ['R_Frontal_Sinus', 'Sinus_Frontal_R']
# Sinus_Maxilry
# ['Maxilry_Sinus', 'Sinus_Maxilry']
# Sinus_Maxilry_L
# ['Sinus_Maxilry_L', 'L_Maxilry_Sinus']
# Sinus_Maxilry_R
# ['R_Maxilry_Sinus', 'Sinus_Maxilry_R']
# Sinus_Sphenoid
# ['Sphenoid_Sinus', 'Sinus_Sphenoid']
# Sinus_Sphenoid_L
# ['Sinus_Sphenoid_L', 'L_Sphenoid_Sinus']
# Sinus_Sphenoid_R
# ['R_Sphenoid_Sinus', 'Sinus_Sphenoid_R']
# Skin
# ['Skin']
# Skin_Perineum
# ['Skin_Perineum', 'Perineum_Skin']
# Skin_Peritoneum
# ['Peritoneum_Skin', 'Skin_Peritoneum']
# Skull
# ['Skull']
# Spc
# ['Spc']
# Spc_Bowel
# ['Spc_Bowel ', 'Bowel_Spc']
# Spc_Bowel_Small
# ['Small_Bowel_Spc', 'Spc_Bowel_Small']
# Spc_Retrophar_L
# ['L_Retrophar_Spc', 'Spc_Retrophar_L']
# Spc_Retrophar_R
# ['Spc_Retrophar_R', 'R_Retrophar_Spc']
# Spc_Retrophars
# ['Retrophars_Spc', 'Spc_Retrophars']
# Spc_Retrosty
# ['Spc_Retrosty', 'Retrosty_Spc']
# Spc_Retrosty_L
# ['L_Retrosty_Spc', 'Spc_Retrosty_L']
# Spc_Retrosty_R
# ['R_Retrosty_Spc', 'Spc_Retrosty_R']
# Spc_Supraclav_L
# ['Spc_Supraclav_L', 'L_Supraclav_Spc']
# Spc_Supraclav_R
# ['Spc_Supraclav_R', 'R_Supraclav_Spc']
# Sphincter_Anal
# ['Anal_Sphincter', 'Sphincter_Anal']
# SpinalCanal
# ['SpinalCanal']
# SpinalCanal_PRV
# ['PRV_SpinalCanal', 'SpinalCanal_PRV']
# SpinalCanal_PRVx
# ['SpinalCanal_PRVx', 'PRVx_SpinalCanal']
# SpinalCord
# ['SpinalCord']
# SpinalCord_Cerv
# ['SpinalCord_Cerv', 'Cerv_SpinalCord']
# SpinalCord_Lum
# ['SpinalCord_Lum', 'Lum_SpinalCord']
# SpinalCord_PRV
# ['PRV_SpinalCord', 'SpinalCord_PRV']
# SpinalCord_PRVxx
# ['PRVxx_SpinalCord', 'SpinalCord_PRVxx']
# SpinalCord_Sac
# ['SpinalCord_Sac', 'Sac_SpinalCord']
# SpinalCord_Thor
# ['SpinalCord_Thor', 'Thor_SpinalCord']
# Spleen
# ['Spleen']
# Spleen_Hilum
# ['Hilum_Spleen', 'Spleen_Hilum']
# Spongiosum
# ['Spongiosum']
# Stapes
# ['Stapes']
# Stapes_L
# ['L_Stapes', 'Stapes_L']
# Stapes_R
# ['Stapes_R', 'R_Stapes']
# Stomach
# ['Stomach']
# Stomach_PRVxx
# ['PRVxx_Stomach', 'Stomach_PRVxx']
# Strct
# ['Strct ', 'Strct']
# Strct_Suprapatel
# ['Suprapatel_Strct', 'Strct_Suprapatel']
# Surf_Eye
# ['Surf_Eye', 'Eye_Surf']
# SurgicalBed
# ['SurgicalBed']
# Sys_Ventricular
# ['Ventricular_Sys', 'Sys_Ventricular']
# Tendon
# ['Tendon', 'Tendon ']
# Tendon_Quad
# ['Tendon_Quad', 'Quad_Tendon']
# Testis
# ['Testis']
# Testis_L
# ['Testis_L', 'L_Testis']
# Testis_R
# ['R_Testis', 'Testis_R']
# ThecalSac
# ['ThecalSac']
# Thoracic_Duct
# ['Thoracic_Duct', 'Duct_Thoracic']
# Tongue
# ['Tongue']
# Tongue_All
# ['Tongue_All', 'All_Tongue']
# Tongue_Base
# ['Base_Tongue', 'Tongue_Base']
# Tongue_Base_L
# ['L_Base_Tongue', 'Tongue_Base_L']
# Tongue_Base_R
# ['Tongue_Base_R', 'R_Base_Tongue']
# Tongue_Oral
# ['Tongue_Oral', 'Oral_Tongue']
# Tongue_Oral_L
# ['Tongue_Oral_L', 'L_Oral_Tongue']
# Tongue_Oral_R
# ['Tongue_Oral_R', 'R_Oral_Tongue']
# Tonsil
# ['Tonsil']
# Trachea
# ['Trachea']
# Trachea_NAdj
# ['Trachea_NAdj', 'NAdj_Trachea']
# TumorBed
# ['TumorBed']
# Ureter_L
# ['L_Ureter', 'Ureter_L']
# Ureter_R
# ['R_Ureter', 'Ureter_R']
# UreterDivert
# ['UreterDivert']
# Ureters
# ['Ureters']
# Urethra
# ['Urethra']
# Urethra_Prostatc
# ['Prostatc_Urethra', 'Urethra_Prostatc']
# Uterus
# ['Uterus']
# V_Azygos
# ['Azygos_V', 'V_Azygos']
# V_Brachioceph_L
# ['V_Brachioceph_L', 'L_Brachioceph_V']
# V_Brachioceph_R
# ['R_Brachioceph_V', 'V_Brachioceph_R']
# V_Iliac_Ext_L
# ['L_Ext_Iliac_V', 'V_Iliac_Ext_L']
# V_Iliac_Ext_R
# ['R_Ext_Iliac_V', 'V_Iliac_Ext_R']
# V_Iliac_Int_L
# ['V_Iliac_Int_L', 'L_Int_Iliac_V']
# V_Iliac_Int_R
# ['V_Iliac_Int_R', 'R_Int_Iliac_V']
# V_Iliac_L
# ['L_Iliac_V', 'V_Iliac_L']
# V_Iliac_R
# ['R_Iliac_V', 'V_Iliac_R']
# V_Jugular
# ['V_Jugular', 'Jugular_V']
# V_Jugular_Ext_L
# ['L_Ext_Jugular_V', 'V_Jugular_Ext_L']
# V_Jugular_Ext_R
# ['R_Ext_Jugular_V', 'V_Jugular_Ext_R']
# V_Jugular_Int_L
# ['L_Int_Jugular_V', 'V_Jugular_Int_L']
# V_Jugular_Int_R
# ['R_Int_Jugular_V', 'V_Jugular_Int_R']
# V_Portal
# ['V_Portal', 'Portal_V']
# V_Pulmonary
# ['Pulmonary_V', 'V_Pulmonary']
# V_Subclavian_L
# ['L_Subclavian_V', 'V_Subclavian_L']
# V_Subclavian_R
# ['V_Subclavian_R', 'R_Subclavian_V']
# V_Subclavians
# ['Subclavians_V', 'V_Subclavians']
# V_Venacava_I
# ['V_Venacava_I', 'I_Venacava_V']
# V_Venacava_S
# ['V_Venacava_S', 'S_Venacava_V']
# Vagina
# ['Vagina']
# Vagina_Surf
# ['Surf_Vagina', 'Vagina_Surf']
# VaginalCuff
# ['VaginalCuff']
# Valve
# ['Valve']
# Valve_Aortic
# ['Valve_Aortic', 'Aortic_Valve']
# Valve_Mitral
# ['Valve_Mitral', 'Mitral_Valve']
# Valve_Pulmonic
# ['Valve_Pulmonic', 'Pulmonic_Valve']
# Valve_Tricuspid
# ['Tricuspid_Valve', 'Valve_Tricuspid']
# VB
# ['VB']
# VB_C
# ['VB_C', 'C_VB']
# VB_C1
# ['C1_VB', 'VB_C1']
# VB_C2
# ['C2_VB', 'VB_C2']
# VB_C3
# ['VB_C3', 'C3_VB']
# VB_C4
# ['VB_C4', 'C4_VB']
# VB_C5
# ['C5_VB', 'VB_C5']
# VB_C6
# ['VB_C6', 'C6_VB']
# VB_C7
# ['VB_C7', 'C7_VB']
# VB_L
# ['VB_L', 'L_VB']
# VB_L1
# ['L1_VB', 'VB_L1']
# VB_L2
# ['L2_VB', 'VB_L2']
# VB_L3
# ['L3_VB', 'VB_L3']
# VB_L4
# ['VB_L4', 'L4_VB']
# VB_L5
# ['VB_L5', 'L5_VB']
# VB_S
# ['S_VB', 'VB_S']
# VB_S1
# ['VB_S1', 'S1_VB']
# VB_S2
# ['VB_S2', 'S2_VB']
# VB_S3
# ['VB_S3', 'S3_VB']
# VB_S4
# ['S4_VB', 'VB_S4']
# VB_S5
# ['S5_VB', 'VB_S5']
# VB_T
# ['VB_T', 'T_VB']
# VB_T01
# ['VB_T01', 'T01_VB']
# VB_T02
# ['VB_T02', 'T02_VB']
# VB_T03
# ['VB_T03', 'T03_VB']
# VB_T04
# ['VB_T04', 'T04_VB']
# VB_T05
# ['T05_VB', 'VB_T05']
# VB_T06
# ['VB_T06', 'T06_VB']
# VB_T07
# ['T07_VB', 'VB_T07']
# VB_T08
# ['T08_VB', 'VB_T08']
# VB_T09
# ['VB_T09', 'T09_VB']
# VB_T10
# ['T10_VB', 'VB_T10']
# VB_T11
# ['VB_T11', 'T11_VB']
# VB_T12
# ['VB_T12', 'T12_VB']
# VBs
# ['VBs']
# Ventricle
# ['Ventricle']
# Ventricle_L
# ['L_Ventricle', 'Ventricle_L']
# Ventricle_R
# ['R_Ventricle', 'Ventricle_R']
# VocalCord_L
# ['L_VocalCord', 'VocalCord_L']
# VocalCord_R
# ['VocalCord_R', 'R_VocalCord']
# VocalCords
# ['VocalCords']
# Vomer
# ['Vomer']
# Vulva
# ['Vulva']
# Wall_Vagina
# ['Vagina_Wall', 'Wall_Vagina']

# %%
from harmonizer_gui import HarmonizerGUI

harmonizer_gui = HarmonizerGUI(harmonizer)
harmonizer_gui.run()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\users\wd982598\.pyenv\pyenv-win\versions\3.10.11\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\harmonizer_gui.py", line 41, in on_value_change
#     int(self.num_results.get()), search_column
# ValueError: invalid literal for int() with base 10: ''
