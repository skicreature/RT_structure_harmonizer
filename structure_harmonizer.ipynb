# %%
import os
import fnmatch
import pydicom
from pydicom import dcmread
import numpy as np
import pandas as pd
from openpyxl import load_workbook
from fuzzywuzzy import fuzz
import re
from structure_harmonizer import StructureHarmonizer
import pathlib
#from structure_regex import generate_structure_name

# set the directory to search
# directory = '/pct_ids/users/wd982598/test_requite'
directory = pathlib.Path(r'C:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\test_requite')
output_file =pathlib.Path(r'structure_dictionary.csv')
TG_263_file_path=pathlib.Path(r'C:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\TG263_Nomenclature_Worksheet_20170815.xls')
#directory = '/mnt/t/Batch_1/'

# Define the match quality threshold
threshold = 88

# Create an instance of StructureHarmonizer and call the harmonize_structures method
harmonizer = StructureHarmonizer(
    directory, 
    output_file, 
    TG_263_file_path, 
    threshold=threshold, 
    roi_dict_path='json_roi_dict.json'
    )
# Out:
# c:\Users\wd982598\.virtualenvs\structure_harmonization-AfCjJfLJ\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
harmonizer.load_json_roi_dict(harmonizer.roi_dict_path)
harmonizer.get_all_TG263names()

# %%
roi_dict_size = len(harmonizer.roi_dict)
TG263_dict_size = len(harmonizer.TG263name_dict)
print('roi_dict_size: ', roi_dict_size, '||', 'TG263_dict_size: ', TG263_dict_size)
# Out:
# roi_dict_size:  3555 || TG263_dict_size:  1280

# %%
harmonizer.update_harmonized_df()
harmonizer.harmonized_df
# Out:
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# ...
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
# c:\Users\wd982598\Code\Jupyter-sandbox\REQUITE_Prostate\structure_harmonization\structure_harmonizer.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.harmonized_df = self.harmonized_df.assign(**new_columns)
#                              dummy_column  A_Aorta  Aorta_A  A_Aorta_Asc  \
# dummy_index                           NaN      NaN      NaN          NaN
#  intestino tc1                        NaN      NaN      NaN          NaN
#  paloma                               NaN      NaN      NaN          NaN
# (D) Blad OL                           NaN      NaN      NaN          NaN
# (D) Blad Opt                          NaN      NaN      NaN          NaN
# ...                                   ...      ...      ...          ...
# zone_caudaal_rechts                   NaN      NaN      NaN          NaN
# zone_craniaal                         NaN      NaN      NaN          NaN
# zrim_PTV_8mm                          NaN      NaN      NaN          NaN
# zrim_PTV_GTV_Lnn_All_8mm              NaN      NaN      NaN          NaN
# zrim_PTV_GTV_Lnn_All_8mm_old          NaN      NaN      NaN          NaN
#
#                               Asc_Aorta_A  A_Brachiocephls  Brachiocephls_A  \
# dummy_index                           NaN              NaN              NaN
#  intestino tc1                        NaN              NaN              NaN
#  paloma                               NaN              NaN              NaN
# (D) Blad OL                           NaN              NaN              NaN
# (D) Blad Opt                          NaN              NaN              NaN
# ...                                   ...              ...              ...
# zone_caudaal_rechts                   NaN              NaN              NaN
# zone_craniaal                         NaN              NaN              NaN
# zrim_PTV_8mm                          NaN              NaN              NaN
# zrim_PTV_GTV_Lnn_All_8mm              NaN              NaN              NaN
# zrim_PTV_GTV_Lnn_All_8mm_old          NaN              NaN              NaN
#
#                               A_Carotid  Carotid_A  A_Carotid_L  ...  \
# dummy_index                         NaN        NaN          NaN  ...
#  intestino tc1                      NaN        NaN          NaN  ...
#  paloma                             NaN        NaN          NaN  ...
# (D) Blad OL                         NaN        NaN          NaN  ...
# (D) Blad Opt                        NaN        NaN          NaN  ...
# ...                                 ...        ...          ...  ...
# zone_caudaal_rechts                 NaN        NaN          NaN  ...
# zone_craniaal                       NaN        NaN          NaN  ...
# zrim_PTV_8mm                        NaN        NaN          NaN  ...
# zrim_PTV_GTV_Lnn_All_8mm            NaN        NaN          NaN  ...
# zrim_PTV_GTV_Lnn_All_8mm_old        NaN        NaN          NaN  ...
#
#                               R_Ventricle  VocalCord_L  L_VocalCord  \
# dummy_index                           NaN          NaN          NaN
#  intestino tc1                        NaN          NaN          NaN
#  paloma                               NaN          NaN          NaN
# (D) Blad OL                           NaN          NaN          NaN
# (D) Blad Opt                          NaN          NaN          NaN
# ...                                   ...          ...          ...
# zone_caudaal_rechts                   NaN          NaN          NaN
# zone_craniaal                         NaN          NaN          NaN
# zrim_PTV_8mm                          NaN          NaN          NaN
# zrim_PTV_GTV_Lnn_All_8mm              NaN          NaN          NaN
# zrim_PTV_GTV_Lnn_All_8mm_old          NaN          NaN          NaN
#
#                               VocalCord_R  R_VocalCord  VocalCords  Vomer  \
# dummy_index                           NaN          NaN         NaN    NaN
#  intestino tc1                        NaN          NaN         NaN    NaN
#  paloma                               NaN          NaN         NaN    NaN
# (D) Blad OL                           NaN          NaN         NaN    NaN
# (D) Blad Opt                          NaN          NaN         NaN    NaN
# ...                                   ...          ...         ...    ...
# zone_caudaal_rechts                   NaN          NaN         NaN    NaN
# zone_craniaal                         NaN          NaN         NaN    NaN
# zrim_PTV_8mm                          NaN          NaN         NaN    NaN
# zrim_PTV_GTV_Lnn_All_8mm              NaN          NaN         NaN    NaN
# zrim_PTV_GTV_Lnn_All_8mm_old          NaN          NaN         NaN    NaN
#
#                               Vulva  Wall_Vagina  Vagina_Wall
# dummy_index                     NaN          NaN          NaN
#  intestino tc1                  NaN          NaN          NaN
#  paloma                         NaN          NaN          NaN
# (D) Blad OL                     NaN          NaN          NaN
# (D) Blad Opt                    NaN          NaN          NaN
# ...                             ...          ...          ...
# zone_caudaal_rechts             NaN          NaN          NaN
# zone_craniaal                   NaN          NaN          NaN
# zrim_PTV_8mm                    NaN          NaN          NaN
# zrim_PTV_GTV_Lnn_All_8mm        NaN          NaN          NaN
# zrim_PTV_GTV_Lnn_All_8mm_old    NaN          NaN          NaN
#
# [3556 rows x 1281 columns]
